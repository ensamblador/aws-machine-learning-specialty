# %%
import numpy as np
import boto3
import sagemaker
import io
import sagemaker.amazon.common as smac
import os
import pandas as pd
sagemaker_session = sagemaker.Session()

# %%
dataset_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip'
s3_prefix = 'aws-machine-learning-specialty/algorithms/linear-lerner/regression'
s3_bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ### Descargamos los Dataset
#
# Descargamos desde UCI el dataset de Bike Sharing
#
# https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip

# %%
# !wget -P . $dataset_url 
local_filename = dataset_url.split('/')[-1]
# !unzip $local_filename  
# !rm $local_filename
# Out:
# --2021-01-30 19:19:06--  https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 279992 (273K) [application/x-httpd-php]
# Saving to: ‘./Bike-Sharing-Dataset.zip’
#
# Bike-Sharing-Datase 100%[===================>] 273.43K   999KB/s    in 0.3s
#
# 2021-01-30 19:19:07 (999 KB/s) - ‘./Bike-Sharing-Dataset.zip’ saved [279992/279992]
#
# Archive:  Bike-Sharing-Dataset.zip
#   inflating: Readme.txt
#   inflating: day.csv
#   inflating: hour.csv

# %%
# !cat Readme.txt
# Out:
# ==========================================
# Bike Sharing Dataset
# ==========================================
#
# Hadi Fanaee-T
#
# Laboratory of Artificial Intelligence and Decision Support (LIAAD), University of Porto
# INESC Porto, Campus da FEUP
# Rua Dr. Roberto Frias, 378
# 4200 - 465 Porto, Portugal
#
#
# =========================================
# Background
# =========================================
#
# Bike sharing systems are new generation of traditional bike rentals where whole process from membership, rental and return
# back has become automatic. Through these systems, user is able to easily rent a bike from a particular position and return
# back at another position. Currently, there are about over 500 bike-sharing programs around the world which is composed of
# over 500 thousands bicycles. Today, there exists great interest in these systems due to their important role in traffic,
# environmental and health issues.
#
# Apart from interesting real world applications of bike sharing systems, the characteristics of data being generated by
# these systems make them attractive for the research. Opposed to other transport services such as bus or subway, the duration
# of travel, departure and arrival position is explicitly recorded in these systems. This feature turns bike sharing system into
# a virtual sensor network that can be used for sensing mobility in the city. Hence, it is expected that most of important
# events in the city could be detected via monitoring these data.
#
# =========================================
# Data Set
# =========================================
# Bike-sharing rental process is highly correlated to the environmental and seasonal settings. For instance, weather conditions,
# precipitation, day of week, season, hour of the day, etc. can affect the rental behaviors. The core data set is related to
# the two-year historical log corresponding to years 2011 and 2012 from Capital Bikeshare system, Washington D.C., USA which is
# publicly available in http://capitalbikeshare.com/system-data. We aggregated the data on two hourly and daily basis and then
# extracted and added the corresponding weather and seasonal information. Weather information are extracted from http://www.freemeteo.com.
#
# =========================================
# Associated tasks
# =========================================
#
# 	- Regression:
# 		Predication of bike rental count hourly or daily based on the environmental and seasonal settings.
#
# 	- Event and Anomaly Detection:
# 		Count of rented bikes are also correlated to some events in the town which easily are traceable via search engines.
# 		For instance, query like "2012-10-30 washington d.c." in Google returns related results to Hurricane Sandy. Some of the important events are
# 		identified in [1]. Therefore the data can be used for validation of anomaly or event detection algorithms as well.
#
#
# =========================================
# Files
# =========================================
#
# 	- Readme.txt
# 	- hour.csv : bike sharing counts aggregated on hourly basis. Records: 17379 hours
# 	- day.csv - bike sharing counts aggregated on daily basis. Records: 731 days
#
#
# =========================================
# Dataset characteristics
# =========================================
# Both hour.csv and day.csv have the following fields, except hr which is not available in day.csv
#
# 	- instant: record index
# 	- dteday : date
# 	- season : season (1:springer, 2:summer, 3:fall, 4:winter)
# 	- yr : year (0: 2011, 1:2012)
# 	- mnth : month ( 1 to 12)
# 	- hr : hour (0 to 23)
# 	- holiday : weather day is holiday or not (extracted from http://dchr.dc.gov/page/holiday-schedule)
# 	- weekday : day of the week
# 	- workingday : if day is neither weekend nor holiday is 1, otherwise is 0.
# 	+ weathersit :
# 		- 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 		- 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 		- 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
# 		- 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# 	- temp : Normalized temperature in Celsius. The values are divided to 41 (max)
# 	- atemp: Normalized feeling temperature in Celsius. The values are divided to 50 (max)
# 	- hum: Normalized humidity. The values are divided to 100 (max)
# 	- windspeed: Normalized wind speed. The values are divided to 67 (max)
# 	- casual: count of casual users
# 	- registered: count of registered users
# 	- cnt: count of total rental bikes including both casual and registered
#
# =========================================
# License
# =========================================
# Use of this dataset in publications must be cited to the following publication:
#
# [1] Fanaee-T, Hadi, and Gama, Joao, "Event labeling combining ensemble detectors and background knowledge", Progress in Artificial Intelligence (2013): pp. 1-15, Springer Berlin Heidelberg, doi:10.1007/s13748-013-0040-3.
#
# @article{
# 	year={2013},
# 	issn={2192-6352},
# 	journal={Progress in Artificial Intelligence},
# 	doi={10.1007/s13748-013-0040-3},
# 	title={Event labeling combining ensemble detectors and background knowledge},
# 	url={http://dx.doi.org/10.1007/s13748-013-0040-3},
# 	publisher={Springer Berlin Heidelberg},
# 	keywords={Event labeling; Event detection; Ensemble learning; Background knowledge},
# 	author={Fanaee-T, Hadi and Gama, Joao},
# 	pages={1-15}
# }
#
# =========================================
# Contact
# =========================================
#
# For further information about this dataset please contact Hadi Fanaee-T (hadi.fanaee@fe.up.pt)

# %%
# !head day.csv
# Out:
# instant,dteday,season,yr,mnth,holiday,weekday,workingday,weathersit,temp,atemp,hum,windspeed,casual,registered,cnt
# 1,2011-01-01,1,0,1,0,6,0,2,0.344167,0.363625,0.805833,0.160446,331,654,985
# 2,2011-01-02,1,0,1,0,0,0,2,0.363478,0.353739,0.696087,0.248539,131,670,801
# 3,2011-01-03,1,0,1,0,1,1,1,0.196364,0.189405,0.437273,0.248309,120,1229,1349
# 4,2011-01-04,1,0,1,0,2,1,1,0.2,0.212122,0.590435,0.160296,108,1454,1562
# 5,2011-01-05,1,0,1,0,3,1,1,0.226957,0.22927,0.436957,0.1869,82,1518,1600
# 6,2011-01-06,1,0,1,0,4,1,1,0.204348,0.233209,0.518261,0.0895652,88,1518,1606
# 7,2011-01-07,1,0,1,0,5,1,2,0.196522,0.208839,0.498696,0.168726,148,1362,1510
# 8,2011-01-08,1,0,1,0,6,0,2,0.165,0.162254,0.535833,0.266804,68,891,959
# 9,2011-01-09,1,0,1,0,0,0,1,0.138333,0.116175,0.434167,0.36195,54,768,822

# %% [markdown]
# ### Convertir en Pandas Dataframe y Preparar

# %%
dataset = pd.read_csv('day.csv')
dataset.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# Un poco de feature Engineering

# %%
dataset['dteday'] = dataset['dteday'].str.replace("-","")
dataset.head()
# Out:
#    instant    dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  20110101       1   0     1        0        6           0
# 1        2  20110102       1   0     1        0        0           0
# 2        3  20110103       1   0     1        0        1           1
# 3        4  20110104       1   0     1        0        2           1
# 4        5  20110105       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# Randomize y Split

# %%
train_data, test_data = np.split(dataset.sample(frac=1, random_state=1729), [int(0.7 * len(dataset))])
print(train_data.shape, test_data.shape)
# Out:
# (511, 16) (220, 16)

# %% [markdown]
# Separar las features y Labels

# %%
feature_dataset = train_data[['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
                           'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered' ]]
features = np.array(feature_dataset.values).astype('float32')

label_dataset= train_data[['cnt']]
labels = np.array(label_dataset.values).astype('float32')
labels_vec = np.squeeze(np.asarray(labels))      #Remueve los array de 1d y deja los valores.

# %% [markdown]
# Prepara Protobuf IO

# %%
buffer = io.BytesIO()
smac.write_numpy_to_dense_tensor(buffer, features, labels_vec)
buffer.seek(0)

boto3.resource('s3').Bucket(s3_bucket).Object(os.path.join(s3_prefix, 'train')).upload_fileobj(buffer)
s3_training_data_location = 's3://{}/{}/train'.format(s3_bucket, s3_prefix)
print('training dataset will be uploaded to: {}'.format(s3_training_data_location))
# Out:
# training dataset will be uploaded to: s3://sagemaker-us-east-1-844626608976/aws-machine-learning-specialty/algorithms/linear-lerner/regression/train

# %%
output_location = 's3://{}/{}/output'.format(s3_bucket, s3_prefix)
print('model artifacts will be uploaded to: {}'.format(output_location))
# Out:
# model artifacts will be uploaded to: s3://sagemaker-us-east-1-844626608976/aws-machine-learning-specialty/algorithms/linear-lerner/regression/output

# %% [markdown]
# ### Obtiene training image

# %%
linear_container = sagemaker.image_uris.retrieve('linear-learner', boto3.Session().region_name)
linear_container
# Out:
# '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:1'

# %% [markdown]
# ### Entrena el modelo

# %%
role = sagemaker.get_execution_role()

# Role, Instance type / count, output location, session
linear = sagemaker.estimator.Estimator(linear_container,
                                       role=role, 
                                       instance_count=1, 
                                       instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sagemaker_session)


# Provide the number of features identified during data preparation
# Provide the predictor_type 

linear.set_hyperparameters(feature_dim=len(feature_dataset.columns) , #15
                           mini_batch_size=4,
                           predictor_type='regressor')

#entrena el modelo usando la data de training
linear.fit({'train': s3_training_data_location})
# Out:
# 2021-01-30 21:07:07 Starting - Starting the training job...
# 2021-01-30 21:07:30 Starting - Launching requested ML instancesProfilerReport-1612040827: InProgress
# ......
# 2021-01-30 21:08:31 Starting - Preparing the instances for training.........
# 2021-01-30 21:10:08 Downloading - Downloading input data
# 2021-01-30 21:10:08 Training - Downloading the training image...
# 2021-01-30 21:10:32 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [01/30/2021 21:10:33 INFO 140403057502016] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/30/2021 21:10:33 INFO 140403057502016] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'15', u'mini_batch_size': u'4', u'predictor_type': u'regressor'}
# [01/30/2021 21:10:33 INFO 140403057502016] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'4', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [01/30/2021 21:10:33 WARNING 140403057502016] Loggers have already been setup.
# Process 1 is a worker.
# [01/30/2021 21:10:33 INFO 140403057502016] Using default worker.
# [01/30/2021 21:10:34 INFO 140403057502016] Checkpoint loading and saving are disabled.
# [2021-01-30 21:10:34.158] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 15, "num_examples": 1, "num_bytes": 416}
# [01/30/2021 21:10:34 INFO 140403057502016] Create Store: local
# [2021-01-30 21:10:34.996] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 836, "num_examples": 128, "num_bytes": 53144}
# [01/30/2021 21:10:34 INFO 140403057502016] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fb1c2e01d10>
# [01/30/2021 21:10:34 INFO 140403057502016] Scaling model computed with parameters:
#  {'stdev_weight':
# [2.1629556e+02 5.0257788e+03 1.1230946e+00 4.9953073e-01 3.5005352e+00
#  1.5791038e-01 2.0275114e+00 4.6975514e-01 5.3916538e-01 1.8521294e-01
#  1.6500628e-01 1.4519952e-01 7.7296920e-02 6.8667987e+02 1.5956223e+03]
# <NDArray 15 @cpu(0)>, 'stdev_label':
# [1980.7333]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [4518.01]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [3.7352948e+02 2.0115876e+07 2.4783452e+00 5.2165383e-01 6.5137796e+00
#  2.5590543e-02 3.0374014e+00 6.7125994e-01 1.3799212e+00 4.9031097e-01
#  4.6974406e-01 6.2344176e-01 1.8905912e-01 8.4455292e+02 3.6734595e+03]
# <NDArray 15 @cpu(0)>}
# [01/30/2021 21:10:35 INFO 140403057502016] nvidia-smi took: 0.0252730846405 secs to identify 0 gpus
# [01/30/2021 21:10:35 INFO 140403057502016] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 129, "sum": 129.0, "min": 129}, "Total Records Seen": {"count": 1, "max": 515, "sum": 515.0, "min": 515}, "Max Records Seen Between Resets": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1612041035.099875, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1612041035.099835}
#
# [2021-01-30 21:10:37.586] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 2486, "num_examples": 128, "num_bytes": 53144}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.16052806017715043, "sum": 0.16052806017715043, "min": 0.16052806017715043}}, "EndTime": 1612041037.587082, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.586836}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.19196429577707422, "sum": 0.19196429577707422, "min": 0.19196429577707422}}, "EndTime": 1612041037.587191, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587168}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.22893963263307765, "sum": 0.22893963263307765, "min": 0.22893963263307765}}, "EndTime": 1612041037.58732, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587298}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.19839403080922646, "sum": 0.19839403080922646, "min": 0.19839403080922646}}, "EndTime": 1612041037.58739, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587371}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.1863560878367376, "sum": 0.1863560878367376, "min": 0.1863560878367376}}, "EndTime": 1612041037.587457, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587437}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.20223060603744872, "sum": 0.20223060603744872, "min": 0.20223060603744872}}, "EndTime": 1612041037.587519, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587502}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.17309983037082172, "sum": 0.17309983037082172, "min": 0.17309983037082172}}, "EndTime": 1612041037.587583, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587566}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.18040149569086086, "sum": 0.18040149569086086, "min": 0.18040149569086086}}, "EndTime": 1612041037.587656, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587638}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.16733683961788265, "sum": 0.16733683961788265, "min": 0.16733683961788265}}, "EndTime": 1612041037.587717, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.5877}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.19310279913231965, "sum": 0.19310279913231965, "min": 0.19310279913231965}}, "EndTime": 1612041037.587788, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587769}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.24475871903389165, "sum": 0.24475871903389165, "min": 0.24475871903389165}}, "EndTime": 1612041037.587862, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587844}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.19505924395080215, "sum": 0.19505924395080215, "min": 0.19505924395080215}}, "EndTime": 1612041037.587933, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587915}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.1632513598049441, "sum": 0.1632513598049441, "min": 0.1632513598049441}}, "EndTime": 1612041037.587995, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.587978}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.23808326184434273, "sum": 0.23808326184434273, "min": 0.23808326184434273}}, "EndTime": 1612041037.588065, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588048}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.18988217643506122, "sum": 0.18988217643506122, "min": 0.18988217643506122}}, "EndTime": 1612041037.588136, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588118}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.1847415532674787, "sum": 0.1847415532674787, "min": 0.1847415532674787}}, "EndTime": 1612041037.588206, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588189}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.23367431635535726, "sum": 0.23367431635535726, "min": 0.23367431635535726}}, "EndTime": 1612041037.588277, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588259}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.27239442971997024, "sum": 0.27239442971997024, "min": 0.27239442971997024}}, "EndTime": 1612041037.588348, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.58833}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.23651966435365437, "sum": 0.23651966435365437, "min": 0.23651966435365437}}, "EndTime": 1612041037.58841, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588393}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.23676523716027637, "sum": 0.23676523716027637, "min": 0.23676523716027637}}, "EndTime": 1612041037.588472, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588454}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.29988349956555627, "sum": 0.29988349956555627, "min": 0.29988349956555627}}, "EndTime": 1612041037.588533, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588516}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.29931144787394626, "sum": 0.29931144787394626, "min": 0.29931144787394626}}, "EndTime": 1612041037.588593, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588576}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.2837523394300947, "sum": 0.2837523394300947, "min": 0.2837523394300947}}, "EndTime": 1612041037.588654, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588637}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.2978345353053663, "sum": 0.2978345353053663, "min": 0.2978345353053663}}, "EndTime": 1612041037.588714, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588696}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9358175011337038, "sum": 0.9358175011337038, "min": 0.9358175011337038}}, "EndTime": 1612041037.588773, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588756}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9407277627606091, "sum": 0.9407277627606091, "min": 0.9407277627606091}}, "EndTime": 1612041037.588832, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588816}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9414003666666314, "sum": 0.9414003666666314, "min": 0.9414003666666314}}, "EndTime": 1612041037.588891, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588875}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.933111857124201, "sum": 0.933111857124201, "min": 0.933111857124201}}, "EndTime": 1612041037.588957, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.588939}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0353654878521998, "sum": 1.0353654878521998, "min": 1.0353654878521998}}, "EndTime": 1612041037.589018, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.589001}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0517654985365437, "sum": 1.0517654985365437, "min": 1.0517654985365437}}, "EndTime": 1612041037.589078, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.589062}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0379421475130741, "sum": 1.0379421475130741, "min": 1.0379421475130741}}, "EndTime": 1612041037.589145, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.589127}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0354009825061625, "sum": 1.0354009825061625, "min": 1.0354009825061625}}, "EndTime": 1612041037.589206, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041037.589189}
#
# [01/30/2021 21:10:37 INFO 140403057502016] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.160528060177
# [01/30/2021 21:10:37 INFO 140403057502016] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=0.160528060177
# [01/30/2021 21:10:37 INFO 140403057502016] Epoch 0: Loss improved. Updating best model
# [01/30/2021 21:10:37 INFO 140403057502016] Saving model for epoch: 0
# [01/30/2021 21:10:37 INFO 140403057502016] Saved checkpoint to "/tmp/tmpiwIbi6/mx-mod-0000.params"
# [01/30/2021 21:10:37 INFO 140403057502016] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Batches Since Last Reset": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Records Since Last Reset": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Total Batches Seen": {"count": 1, "max": 257, "sum": 257.0, "min": 257}, "Total Records Seen": {"count": 1, "max": 1026, "sum": 1026.0, "min": 1026}, "Max Records Seen Between Resets": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1612041037.601443, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1612041035.100118}
#
# [01/30/2021 21:10:37 INFO 140403057502016] #throughput_metric: host=algo-1, train throughput=204.281920555 records/second
# [2021-01-30 21:10:40.430] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 2828, "num_examples": 128, "num_bytes": 53144}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.04358741047418141, "sum": 0.04358741047418141, "min": 0.04358741047418141}}, "EndTime": 1612041040.430519, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.430285}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.04950974154488667, "sum": 0.04950974154488667, "min": 0.04950974154488667}}, "EndTime": 1612041040.430621, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.4306}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.06218577625860614, "sum": 0.06218577625860614, "min": 0.06218577625860614}}, "EndTime": 1612041040.430692, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.430672}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.04684826863313636, "sum": 0.04684826863313636, "min": 0.04684826863313636}}, "EndTime": 1612041040.43076, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.430743}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.056497765769155356, "sum": 0.056497765769155356, "min": 0.056497765769155356}}, "EndTime": 1612041040.430822, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.430805}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.22712329336200057, "sum": 0.22712329336200057, "min": 0.22712329336200057}}, "EndTime": 1612041040.430887, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.430869}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.058677930549872435, "sum": 0.058677930549872435, "min": 0.058677930549872435}}, "EndTime": 1612041040.430958, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.430939}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.05098556914168784, "sum": 0.05098556914168784, "min": 0.05098556914168784}}, "EndTime": 1612041040.431025, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431007}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.04715398351632528, "sum": 0.04715398351632528, "min": 0.04715398351632528}}, "EndTime": 1612041040.431092, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431074}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.04257771649808571, "sum": 0.04257771649808571, "min": 0.04257771649808571}}, "EndTime": 1612041040.431155, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431138}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.061162005393127876, "sum": 0.061162005393127876, "min": 0.061162005393127876}}, "EndTime": 1612041040.431215, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431199}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.04716115284850454, "sum": 0.04716115284850454, "min": 0.04716115284850454}}, "EndTime": 1612041040.431272, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431258}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.09489714007597329, "sum": 0.09489714007597329, "min": 0.09489714007597329}}, "EndTime": 1612041040.431324, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431309}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.10293417448896593, "sum": 0.10293417448896593, "min": 0.10293417448896593}}, "EndTime": 1612041040.431391, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431373}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.029089277057439147, "sum": 0.029089277057439147, "min": 0.029089277057439147}}, "EndTime": 1612041040.43146, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431441}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.12368177407234174, "sum": 0.12368177407234174, "min": 0.12368177407234174}}, "EndTime": 1612041040.431526, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431508}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.11803881373388443, "sum": 0.11803881373388443, "min": 0.11803881373388443}}, "EndTime": 1612041040.431592, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431574}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.12116113057411386, "sum": 0.12116113057411386, "min": 0.12116113057411386}}, "EndTime": 1612041040.431654, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431636}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.12058089486337964, "sum": 0.12058089486337964, "min": 0.12058089486337964}}, "EndTime": 1612041040.431725, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431706}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.1202958659158917, "sum": 0.1202958659158917, "min": 0.1202958659158917}}, "EndTime": 1612041040.431777, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431761}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.24239255420452965, "sum": 0.24239255420452965, "min": 0.24239255420452965}}, "EndTime": 1612041040.431831, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431815}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.2567848609082078, "sum": 0.2567848609082078, "min": 0.2567848609082078}}, "EndTime": 1612041040.431896, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431879}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.24493828214206328, "sum": 0.24493828214206328, "min": 0.24493828214206328}}, "EndTime": 1612041040.431947, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431931}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.2578995679725167, "sum": 0.2578995679725167, "min": 0.2578995679725167}}, "EndTime": 1612041040.432004, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.431989}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9385657598242516, "sum": 0.9385657598242516, "min": 0.9385657598242516}}, "EndTime": 1612041040.432054, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.432038}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.939466546384955, "sum": 0.939466546384955, "min": 0.939466546384955}}, "EndTime": 1612041040.432108, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.432092}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9385097582245202, "sum": 0.9385097582245202, "min": 0.9385097582245202}}, "EndTime": 1612041040.432161, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.432145}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9394939517763656, "sum": 0.9394939517763656, "min": 0.9394939517763656}}, "EndTime": 1612041040.432225, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.432208}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0265980186307524, "sum": 1.0265980186307524, "min": 1.0265980186307524}}, "EndTime": 1612041040.432285, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.432267}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0416187357421465, "sum": 1.0416187357421465, "min": 1.0416187357421465}}, "EndTime": 1612041040.432344, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.432327}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0270064436192587, "sum": 1.0270064436192587, "min": 1.0270064436192587}}, "EndTime": 1612041040.432412, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.432394}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0430704269000863, "sum": 1.0430704269000863, "min": 1.0430704269000863}}, "EndTime": 1612041040.432476, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041040.432459}
#
# [01/30/2021 21:10:40 INFO 140403057502016] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.0435874104742
# [01/30/2021 21:10:40 INFO 140403057502016] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=mse_objective, value=0.0290892770574
# [01/30/2021 21:10:40 INFO 140403057502016] Epoch 1: Loss improved. Updating best model
# [01/30/2021 21:10:40 INFO 140403057502016] Saving model for epoch: 1
# [01/30/2021 21:10:40 INFO 140403057502016] Saved checkpoint to "/tmp/tmpalQrSb/mx-mod-0000.params"
# [01/30/2021 21:10:40 INFO 140403057502016] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Batches Since Last Reset": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Records Since Last Reset": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Total Batches Seen": {"count": 1, "max": 385, "sum": 385.0, "min": 385}, "Total Records Seen": {"count": 1, "max": 1537, "sum": 1537.0, "min": 1537}, "Max Records Seen Between Resets": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1612041040.441017, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1612041037.601747}
#
# [01/30/2021 21:10:40 INFO 140403057502016] #throughput_metric: host=algo-1, train throughput=179.967036304 records/second
# [2021-01-30 21:10:42.877] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 2435, "num_examples": 128, "num_bytes": 53144}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0189645591867523, "sum": 0.0189645591867523, "min": 0.0189645591867523}}, "EndTime": 1612041042.877178, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877087}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.022094634444980814, "sum": 0.022094634444980814, "min": 0.022094634444980814}}, "EndTime": 1612041042.877279, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877258}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.031155500096712613, "sum": 0.031155500096712613, "min": 0.031155500096712613}}, "EndTime": 1612041042.877351, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877331}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.02142365254584597, "sum": 0.02142365254584597, "min": 0.02142365254584597}}, "EndTime": 1612041042.877409, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877394}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.026372208439664344, "sum": 0.026372208439664344, "min": 0.026372208439664344}}, "EndTime": 1612041042.877471, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877454}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.1740142761355662, "sum": 0.1740142761355662, "min": 0.1740142761355662}}, "EndTime": 1612041042.877535, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877518}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.08087570387796741, "sum": 0.08087570387796741, "min": 0.08087570387796741}}, "EndTime": 1612041042.877587, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877576}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.1604290156548212, "sum": 0.1604290156548212, "min": 0.1604290156548212}}, "EndTime": 1612041042.877619, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877611}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.023530306127729026, "sum": 0.023530306127729026, "min": 0.023530306127729026}}, "EndTime": 1612041042.877663, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.87765}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.01924019475608668, "sum": 0.01924019475608668, "min": 0.01924019475608668}}, "EndTime": 1612041042.877713, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877697}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.03140252701274494, "sum": 0.03140252701274494, "min": 0.03140252701274494}}, "EndTime": 1612041042.877766, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877751}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.02019291480830834, "sum": 0.02019291480830834, "min": 0.02019291480830834}}, "EndTime": 1612041042.877816, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877801}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.07710627543989305, "sum": 0.07710627543989305, "min": 0.07710627543989305}}, "EndTime": 1612041042.877877, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877859}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.04077450967371816, "sum": 0.04077450967371816, "min": 0.04077450967371816}}, "EndTime": 1612041042.877973, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.877953}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.08664259430035715, "sum": 0.08664259430035715, "min": 0.08664259430035715}}, "EndTime": 1612041042.878042, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878024}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.18606280187130209, "sum": 0.18606280187130209, "min": 0.18606280187130209}}, "EndTime": 1612041042.878102, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878085}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.11585511134086748, "sum": 0.11585511134086748, "min": 0.11585511134086748}}, "EndTime": 1612041042.878162, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878145}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.11726173429243912, "sum": 0.11726173429243912, "min": 0.11726173429243912}}, "EndTime": 1612041042.878214, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878197}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.11611991776630107, "sum": 0.11611991776630107, "min": 0.11611991776630107}}, "EndTime": 1612041042.878268, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878251}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.11755021396239736, "sum": 0.11755021396239736, "min": 0.11755021396239736}}, "EndTime": 1612041042.878329, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878312}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.23303434370804255, "sum": 0.23303434370804255, "min": 0.23303434370804255}}, "EndTime": 1612041042.87839, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878373}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.2681057140053301, "sum": 0.2681057140053301, "min": 0.2681057140053301}}, "EndTime": 1612041042.878453, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878435}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.23217983200676798, "sum": 0.23217983200676798, "min": 0.23217983200676798}}, "EndTime": 1612041042.878521, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878503}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.2678176084676332, "sum": 0.2678176084676332, "min": 0.2678176084676332}}, "EndTime": 1612041042.878591, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878572}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9382112855458353, "sum": 0.9382112855458353, "min": 0.9382112855458353}}, "EndTime": 1612041042.878645, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878634}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9391309612349966, "sum": 0.9391309612349966, "min": 0.9391309612349966}}, "EndTime": 1612041042.878701, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878685}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.938278174482462, "sum": 0.938278174482462, "min": 0.938278174482462}}, "EndTime": 1612041042.878736, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878727}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9393801731387461, "sum": 0.9393801731387461, "min": 0.9393801731387461}}, "EndTime": 1612041042.87878, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878765}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0214207511483215, "sum": 1.0214207511483215, "min": 1.0214207511483215}}, "EndTime": 1612041042.878839, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878823}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.043382975998826, "sum": 1.043382975998826, "min": 1.043382975998826}}, "EndTime": 1612041042.878897, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878881}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0215180218806417, "sum": 1.0215180218806417, "min": 1.0215180218806417}}, "EndTime": 1612041042.878956, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.878939}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0446985065350383, "sum": 1.0446985065350383, "min": 1.0446985065350383}}, "EndTime": 1612041042.879004, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041042.87899}
#
# [01/30/2021 21:10:42 INFO 140403057502016] #quality_metric: host=algo-1, epoch=2, train mse_objective <loss>=0.0189645591868
# [01/30/2021 21:10:42 INFO 140403057502016] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=mse_objective, value=0.0189645591868
# [01/30/2021 21:10:42 INFO 140403057502016] Epoch 2: Loss improved. Updating best model
# [01/30/2021 21:10:42 INFO 140403057502016] Saving model for epoch: 2
# [01/30/2021 21:10:42 INFO 140403057502016] Saved checkpoint to "/tmp/tmphUBiY2/mx-mod-0000.params"
# [01/30/2021 21:10:42 INFO 140403057502016] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Batches Since Last Reset": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Records Since Last Reset": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Total Batches Seen": {"count": 1, "max": 513, "sum": 513.0, "min": 513}, "Total Records Seen": {"count": 1, "max": 2048, "sum": 2048.0, "min": 2048}, "Max Records Seen Between Resets": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1612041042.886376, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 2}, "StartTime": 1612041040.441308}
#
# [01/30/2021 21:10:42 INFO 140403057502016] #throughput_metric: host=algo-1, train throughput=208.98104672 records/second
# [2021-01-30 21:10:45.349] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 2462, "num_examples": 128, "num_bytes": 53144}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.008805903522013577, "sum": 0.008805903522013577, "min": 0.008805903522013577}}, "EndTime": 1612041045.349496, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.349408}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.010035796299958087, "sum": 0.010035796299958087, "min": 0.010035796299958087}}, "EndTime": 1612041045.349583, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.349569}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.01652053258506449, "sum": 0.01652053258506449, "min": 0.01652053258506449}}, "EndTime": 1612041045.349646, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.349628}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.009753533717617027, "sum": 0.009753533717617027, "min": 0.009753533717617027}}, "EndTime": 1612041045.349712, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.349693}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.04978037329654642, "sum": 0.04978037329654642, "min": 0.04978037329654642}}, "EndTime": 1612041045.349776, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.349758}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.02264498351838469, "sum": 0.02264498351838469, "min": 0.02264498351838469}}, "EndTime": 1612041045.34984, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.349821}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0067927804076585805, "sum": 0.0067927804076585805, "min": 0.0067927804076585805}}, "EndTime": 1612041045.349936, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.349894}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.4153731397140448, "sum": 0.4153731397140448, "min": 0.4153731397140448}}, "EndTime": 1612041045.350012, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.349993}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.012747103370603276, "sum": 0.012747103370603276, "min": 0.012747103370603276}}, "EndTime": 1612041045.350078, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.35006}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.008988854494110835, "sum": 0.008988854494110835, "min": 0.008988854494110835}}, "EndTime": 1612041045.350141, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.350125}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.017093795896177804, "sum": 0.017093795896177804, "min": 0.017093795896177804}}, "EndTime": 1612041045.350203, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.350185}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.00930939509380264, "sum": 0.00930939509380264, "min": 0.00930939509380264}}, "EndTime": 1612041045.350267, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.350249}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.013855728663492207, "sum": 0.013855728663492207, "min": 0.013855728663492207}}, "EndTime": 1612041045.350327, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.350311}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.49084578617292596, "sum": 0.49084578617292596, "min": 0.49084578617292596}}, "EndTime": 1612041045.350389, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.350372}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.04130263033132325, "sum": 0.04130263033132325, "min": 0.04130263033132325}}, "EndTime": 1612041045.350451, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.350435}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.21276059661493232, "sum": 0.21276059661493232, "min": 0.21276059661493232}}, "EndTime": 1612041045.350515, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.350497}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.11530558871449977, "sum": 0.11530558871449977, "min": 0.11530558871449977}}, "EndTime": 1612041045.35058, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.350561}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.11747510986417298, "sum": 0.11747510986417298, "min": 0.11747510986417298}}, "EndTime": 1612041045.350643, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1612041045.350626}
#
# ...
# [01/30/2021 21:11:10 INFO 140403057502016] Saved checkpoint to "/tmp/tmpUjoyNu/mx-mod-0000.params"
# [01/30/2021 21:11:10 INFO 140403057502016] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Batches Since Last Reset": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Records Since Last Reset": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Total Batches Seen": {"count": 1, "max": 1921, "sum": 1921.0, "min": 1921}, "Total Records Seen": {"count": 1, "max": 7669, "sum": 7669.0, "min": 7669}, "Max Records Seen Between Resets": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1612041070.75155, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1612041068.527374}
#
# [01/30/2021 21:11:10 INFO 140403057502016] #throughput_metric: host=algo-1, train throughput=229.737965146 records/second
# [2021-01-30 21:11:13.372] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 32, "duration": 2621, "num_examples": 128, "num_bytes": 53144}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 2.953092880256094e-05, "sum": 2.953092880256094e-05, "min": 2.953092880256094e-05}}, "EndTime": 1612041073.373108, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373024}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 2.0239247214345868e-05, "sum": 2.0239247214345868e-05, "min": 2.0239247214345868e-05}}, "EndTime": 1612041073.373221, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373197}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.00017893365580088657, "sum": 0.00017893365580088657, "min": 0.00017893365580088657}}, "EndTime": 1612041073.373289, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373271}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 4.861882258888355e-07, "sum": 4.861882258888355e-07, "min": 4.861882258888355e-07}}, "EndTime": 1612041073.373357, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373339}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 2.2475345490505335e-06, "sum": 2.2475345490505335e-06, "min": 2.2475345490505335e-06}}, "EndTime": 1612041073.373418, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.3734}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0027499670945621262, "sum": 0.0027499670945621262, "min": 0.0027499670945621262}}, "EndTime": 1612041073.373485, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373467}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 5.453986508347423e-06, "sum": 5.453986508347423e-06, "min": 5.453986508347423e-06}}, "EndTime": 1612041073.373523, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373514}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0015675917184842002, "sum": 0.0015675917184842002, "min": 0.0015675917184842002}}, "EndTime": 1612041073.373556, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373547}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0005050585242981728, "sum": 0.0005050585242981728, "min": 0.0005050585242981728}}, "EndTime": 1612041073.373613, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373596}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.00040421224947370025, "sum": 0.00040421224947370025, "min": 0.00040421224947370025}}, "EndTime": 1612041073.373661, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.37365}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0006758146913437764, "sum": 0.0006758146913437764, "min": 0.0006758146913437764}}, "EndTime": 1612041073.373692, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373684}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.00040300811702391503, "sum": 0.00040300811702391503, "min": 0.00040300811702391503}}, "EndTime": 1612041073.373747, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373731}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0009425262619265058, "sum": 0.0009425262619265058, "min": 0.0009425262619265058}}, "EndTime": 1612041073.373806, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.37379}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.1222473336736613, "sum": 0.1222473336736613, "min": 0.1222473336736613}}, "EndTime": 1612041073.373857, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373846}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0009506345476130643, "sum": 0.0009506345476130643, "min": 0.0009506345476130643}}, "EndTime": 1612041073.373887, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.37388}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.3803841754148795, "sum": 0.3803841754148795, "min": 0.3803841754148795}}, "EndTime": 1612041073.373953, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373934}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.11074139271481476, "sum": 0.11074139271481476, "min": 0.11074139271481476}}, "EndTime": 1612041073.37401, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.373993}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.1174299945783486, "sum": 0.1174299945783486, "min": 0.1174299945783486}}, "EndTime": 1612041073.374075, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374058}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.11073726640123228, "sum": 0.11073726640123228, "min": 0.11073726640123228}}, "EndTime": 1612041073.374141, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374122}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.11745632286770195, "sum": 0.11745632286770195, "min": 0.11745632286770195}}, "EndTime": 1612041073.374202, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374185}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.12720051739276864, "sum": 0.12720051739276864, "min": 0.12720051739276864}}, "EndTime": 1612041073.374265, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374248}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.24625972442064933, "sum": 0.24625972442064933, "min": 0.24625972442064933}}, "EndTime": 1612041073.37433, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374313}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.12721187179526827, "sum": 0.12721187179526827, "min": 0.12721187179526827}}, "EndTime": 1612041073.374383, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374366}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.2462331476276667, "sum": 0.2462331476276667, "min": 0.2462331476276667}}, "EndTime": 1612041073.374454, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374435}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9331530045101962, "sum": 0.9331530045101962, "min": 0.9331530045101962}}, "EndTime": 1612041073.374522, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374504}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9384565462512294, "sum": 0.9384565462512294, "min": 0.9384565462512294}}, "EndTime": 1612041073.374591, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374572}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9331207097926009, "sum": 0.9331207097926009, "min": 0.9331207097926009}}, "EndTime": 1612041073.374654, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374637}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9385005793585552, "sum": 0.9385005793585552, "min": 0.9385005793585552}}, "EndTime": 1612041073.374718, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374699}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9556348420034243, "sum": 0.9556348420034243, "min": 0.9556348420034243}}, "EndTime": 1612041073.374787, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374769}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0306248025983338, "sum": 1.0306248025983338, "min": 1.0306248025983338}}, "EndTime": 1612041073.374861, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374841}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9556345178738354, "sum": 0.9556345178738354, "min": 0.9556345178738354}}, "EndTime": 1612041073.374935, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374916}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0306605892915894, "sum": 1.0306605892915894, "min": 1.0306605892915894}}, "EndTime": 1612041073.375, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041073.374981}
#
# [01/30/2021 21:11:13 INFO 140403057502016] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=2.95309288026e-05
# [01/30/2021 21:11:13 INFO 140403057502016] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=4.86188225889e-07
# [01/30/2021 21:11:13 INFO 140403057502016] Epoch 14: Loss improved. Updating best model
# [01/30/2021 21:11:13 INFO 140403057502016] Saving model for epoch: 14
# [01/30/2021 21:11:13 INFO 140403057502016] Saved checkpoint to "/tmp/tmppGnOIm/mx-mod-0000.params"
# [01/30/2021 21:11:13 INFO 140403057502016] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Batches Since Last Reset": {"count": 1, "max": 128, "sum": 128.0, "min": 128}, "Number of Records Since Last Reset": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Total Batches Seen": {"count": 1, "max": 2049, "sum": 2049.0, "min": 2049}, "Total Records Seen": {"count": 1, "max": 8180, "sum": 8180.0, "min": 8180}, "Max Records Seen Between Resets": {"count": 1, "max": 511, "sum": 511.0, "min": 511}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1612041073.383369, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1612041070.751792}
#
# [01/30/2021 21:11:13 INFO 140403057502016] #throughput_metric: host=algo-1, train throughput=194.170484762 records/second
# [01/30/2021 21:11:13 WARNING 140403057502016] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [01/30/2021 21:11:13 WARNING 140403057502016] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-01-30 21:11:13.384] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 34, "duration": 0, "num_examples": 1, "num_bytes": 416}
# [2021-01-30 21:11:13.540] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 154, "num_examples": 128, "num_bytes": 53144}
# [01/30/2021 21:11:13 INFO 140403057502016] #train_score (algo-1) : ('mse_objective', 1.6772771488197162)
# [01/30/2021 21:11:13 INFO 140403057502016] #train_score (algo-1) : ('mse', 1.6772771488197162)
# [01/30/2021 21:11:13 INFO 140403057502016] #train_score (algo-1) : ('absolute_loss', 1.044000733855186)
# [01/30/2021 21:11:13 INFO 140403057502016] #quality_metric: host=algo-1, train mse_objective <loss>=1.67727714882
# [01/30/2021 21:11:13 INFO 140403057502016] #quality_metric: host=algo-1, train mse <loss>=1.67727714882
# [01/30/2021 21:11:13 INFO 140403057502016] #quality_metric: host=algo-1, train absolute_loss <loss>=1.04400073386
# [01/30/2021 21:11:13 INFO 140403057502016] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 0.0001}
# [01/30/2021 21:11:13 INFO 140403057502016] Saved checkpoint to "/tmp/tmpR1aO99/mx-mod-0000.params"
# [01/30/2021 21:11:13 INFO 140403057502016] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 39663.8400554657, "sum": 39663.8400554657, "min": 39663.8400554657}, "finalize.time": {"count": 1, "max": 158.1418514251709, "sum": 158.1418514251709, "min": 158.1418514251709}, "initialize.time": {"count": 1, "max": 955.4848670959473, "sum": 955.4848670959473, "min": 955.4848670959473}, "check_early_stopping.time": {"count": 15, "max": 1.1589527130126953, "sum": 15.611648559570312, "min": 0.9050369262695312}, "setuptime": {"count": 1, "max": 38.655996322631836, "sum": 38.655996322631836, "min": 38.655996322631836}, "update.time": {"count": 15, "max": 2835.928201675415, "sum": 38238.39735984802, "min": 2222.0070362091064}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1612041073.546742, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1612041034.142618}
#
#
# 2021-01-30 21:11:33 Uploading - Uploading generated training model
# 2021-01-30 21:11:33 Completed - Training job completed
# ProfilerReport-1612040827: NoIssuesFound
# Training seconds: 92
# Billable seconds: 92

# %% [markdown]
# ***(en caso de no tener el objeto Estimator, podemos ir al training job y crearlo desde ahí)***

# %%
job_name = 'linear-learner-2021-01-30-21-07-07-520'
linear_from_job = sagemaker.estimator.Estimator.attach(job_name,sagemaker_session=sagemaker_session)
linear, linear_from_job
# Out:
# 2021-01-30 21:11:33 Starting - Preparing the instances for training
# 2021-01-30 21:11:33 Downloading - Downloading input data
# 2021-01-30 21:11:33 Training - Training image download completed. Training in progress.
# 2021-01-30 21:11:33 Uploading - Uploading generated training model
# 2021-01-30 21:11:33 Completed - Training job completed
# (<sagemaker.estimator.Estimator at 0x7f79f3c73cf8>,
#  <sagemaker.estimator.Estimator at 0x7f79ef349c18>)

# %% [markdown]
# ### Realizando predicciones

# %%
# Deploy the model
linear_predictor = linear_from_job.deploy(initial_instance_count=1,instance_type='ml.c4.xlarge',endpoint_name='bikeshare-sagemaker-regression-v1')
# Out:
# -----------------!

# %% [markdown]
# ***(en caso de no tener el objeto Predictor, podemos ir al endpoint name y crearlo desde ahí)***

# %%
from sagemaker.deserializers import JSONDeserializer
from sagemaker.serializers import CSVSerializer

linear_predictor_from_endpoint  =  sagemaker.predictor.Predictor(
    'bikeshare-sagemaker-regression-v1',
    sagemaker_session=sagemaker_session,
    serializer= CSVSerializer(),
    deserializer=JSONDeserializer()
)
test_feature_dataset = test_data[['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
                           'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered']]

test_actuals = np.array(test_data['cnt'].astype('float32'))
test_features = np.array(test_feature_dataset.values).astype('float32').tolist()

predictions = []
actuals = []
for tf, actual in zip(test_features, test_actuals):
    #print(",".join(map(str, tf)))
    prediction = linear_predictor_from_endpoint.predict(data=tf, initial_args= {'Accept':'text/json'})
    predictions.append(prediction['predictions'][0]['score'])
    actuals.append(actual)
    

predictions_df = pd.DataFrame({'Prediction': predictions, 'Actual': actuals})

# %%
predictions_df['delta'] = predictions_df['Prediction']-predictions_df['Actual']

# %%
predictions_df.describe()
# Out:
#         Prediction       Actual       delta
# count   220.000000   220.000000  220.000000
# mean   4454.957031  4455.009091   -0.052060
# std    1833.343223  1833.758388    1.290251
# min     706.390625   705.000000   -2.828125
# 25%    3192.625000  3193.000000   -0.968750
# 50%    4387.257812  4387.500000   -0.085938
# 75%    5677.617188  5675.500000    0.828125
# max    8394.765625  8395.000000    4.296875

# %%
# Get accuracy using Cosine Similarity method 
from numpy import dot
from numpy.linalg import norm
tolerance = 1e-10
accuracy = (dot(actuals, predictions)/(norm(actuals)*norm(predictions))) * 100
print('accuracy: ', accuracy)
# Out:
# accuracy:  100.0000031367257

# %% [markdown]
# Esto significa que el modelo es muy exacto (obvio no puede ser mayor a 100% pero es muy acertado)

# %% [markdown]
# ### Borrar el Endpoint y Modelo

# %%
linear_predictor_from_endpoint.delete_endpoint()
linear_predictor_from_endpoint.delete_model()

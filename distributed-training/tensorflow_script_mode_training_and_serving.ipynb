# %% [markdown]
# # TensorFlow script mode training and serving
#
# Script mode is a training script format for TensorFlow that lets you execute any TensorFlow training script in SageMaker with minimal modification. The [SageMaker Python SDK](https://github.com/aws/sagemaker-python-sdk) handles transferring your script to a SageMaker training instance. On the training instance, SageMaker's native TensorFlow support sets up training-related environment variables and executes your training script. In this tutorial, we use the SageMaker Python SDK to launch a training job and deploy the trained model.
#
# Script mode supports training with a Python script, a Python module, or a shell script. In this example, we use a Python script to train a classification model on the [MNIST dataset](http://yann.lecun.com/exdb/mnist/). In this example, we will show how easily you can train a SageMaker using TensorFlow 1.x and TensorFlow 2.0 scripts with SageMaker Python SDK. In addition, this notebook demonstrates how to perform real time inference with the [SageMaker TensorFlow Serving container](https://github.com/aws/sagemaker-tensorflow-serving-container). The TensorFlow Serving container is the default inference method for script mode. For full documentation on the TensorFlow Serving container, please visit [here](https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/tensorflow/deploying_tensorflow_serving.rst).

# %% [markdown]
# # Set up the environment
#
# Let's start by setting up the environment:

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
region = sagemaker_session.boto_session.region_name

# %% [markdown]
# ## Training Data
#
# The MNIST dataset has been loaded to the public S3 buckets ``sagemaker-sample-data-<REGION>`` under the prefix ``tensorflow/mnist``. There are four ``.npy`` file under this prefix:
# * ``train_data.npy``
# * ``eval_data.npy``
# * ``train_labels.npy``
# * ``eval_labels.npy``

# %%
training_data_uri = "s3://sagemaker-sample-data-{}/tensorflow/mnist".format(region)

# %% [markdown]
# # Construct a script for distributed training
#
# This tutorial's training script was adapted from TensorFlow's official [CNN MNIST example](https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/tutorials/layers/cnn_mnist.py). We have modified it to handle the ``model_dir`` parameter passed in by SageMaker. This is an S3 path which can be used for data sharing during distributed training and checkpointing and/or model persistence. We have also added an argument-parsing function to handle processing training-related variables.
#
# At the end of the training job we have added a step to export the trained model to the path stored in the environment variable ``SM_MODEL_DIR``, which always points to ``/opt/ml/model``. This is critical because SageMaker uploads all the model artifacts in this folder to S3 at end of training.
#
# Here is the entire script:

# %%
# !pygmentize 'mnist.py'

# TensorFlow 2.1 script
# !pygmentize 'mnist-2.py'
# Out:
# # Copyright 2018-2019 Amazon.com, Inc. or its affiliates. All Rights Reserved.
# #
# # Licensed under the Apache License, Version 2.0 (the "License"). You
# # may not use this file except in compliance with the License. A copy of
# # the License is located at
# #
# #     http://aws.amazon.com/apache2.0/
# #
# # or in the "license" file accompanying this file. This file is
# # distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF
# # ANY KIND, either express or implied. See the License for the specific
# # language governing permissions and limitations under the License.
# """Convolutional Neural Network Estimator for MNIST, built with tf.layers."""
#
# from __future__ import absolute_import, division, print_function
#
# import argparse
# import json
# import logging as _logging
# import os
# import sys as _sys
#
# import numpy as np
# import tensorflow as tf
# from tensorflow.python.platform import tf_logging
#
#
# def cnn_model_fn(features, labels, mode):
#     """Model function for CNN."""
#     # Input Layer
#     # Reshape X to 4-D tensor: [batch_size, width, height, channels]
#     # MNIST images are 28x28 pixels, and have one color channel
#     input_layer = tf.reshape(features["x"], [-1, 28, 28, 1])
#
#     # Convolutional Layer #1
#     # Computes 32 features using a 5x5 filter with ReLU activation.
#     # Padding is added to preserve width and height.
#     # Input Tensor Shape: [batch_size, 28, 28, 1]
#     # Output Tensor Shape: [batch_size, 28, 28, 32]
#     conv1 = tf.layers.conv2d(
#         inputs=input_layer, filters=32, kernel_size=[5, 5], padding="same", activation=tf.nn.relu
#     )
#
#     # Pooling Layer #1
#     # First max pooling layer with a 2x2 filter and stride of 2
#     # Input Tensor Shape: [batch_size, 28, 28, 32]
#     # Output Tensor Shape: [batch_size, 14, 14, 32]
#     pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=[2, 2], strides=2)
#
#     # Convolutional Layer #2
#     # Computes 64 features using a 5x5 filter.
#     # Padding is added to preserve width and height.
#     # Input Tensor Shape: [batch_size, 14, 14, 32]
#     # Output Tensor Shape: [batch_size, 14, 14, 64]
#     conv2 = tf.layers.conv2d(
#         inputs=pool1, filters=64, kernel_size=[5, 5], padding="same", activation=tf.nn.relu
#     )
#
#     # Pooling Layer #2
#     # Second max pooling layer with a 2x2 filter and stride of 2
#     # Input Tensor Shape: [batch_size, 14, 14, 64]
#     # Output Tensor Shape: [batch_size, 7, 7, 64]
#     pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=[2, 2], strides=2)
#
#     # Flatten tensor into a batch of vectors
#     # Input Tensor Shape: [batch_size, 7, 7, 64]
#     # Output Tensor Shape: [batch_size, 7 * 7 * 64]
#     pool2_flat = tf.reshape(pool2, [-1, 7 * 7 * 64])
#
#     # Dense Layer
#     # Densely connected layer with 1024 neurons
#     # Input Tensor Shape: [batch_size, 7 * 7 * 64]
#     # Output Tensor Shape: [batch_size, 1024]
#     dense = tf.layers.dense(inputs=pool2_flat, units=1024, activation=tf.nn.relu)
#
#     # Add dropout operation; 0.6 probability that element will be kept
#     dropout = tf.layers.dropout(
#         inputs=dense, rate=0.4, training=mode == tf.estimator.ModeKeys.TRAIN
#     )
#
#     # Logits layer
#     # Input Tensor Shape: [batch_size, 1024]
#     # Output Tensor Shape: [batch_size, 10]
#     logits = tf.layers.dense(inputs=dropout, units=10)
#
#     predictions = {
#         # Generate predictions (for PREDICT and EVAL mode)
#         "classes": tf.argmax(input=logits, axis=1),
#         # Add `softmax_tensor` to the graph. It is used for PREDICT and by the
#         # `logging_hook`.
#         "probabilities": tf.nn.softmax(logits, name="softmax_tensor"),
#     }
#     if mode == tf.estimator.ModeKeys.PREDICT:
#         return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions)
#
#     # Calculate Loss (for both TRAIN and EVAL modes)
#     loss = tf.losses.sparse_softmax_cross_entropy(labels=labels, logits=logits)
#
#     # Configure the Training Op (for TRAIN mode)
#     if mode == tf.estimator.ModeKeys.TRAIN:
#         optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.001)
#         train_op = optimizer.minimize(loss=loss, global_step=tf.train.get_global_step())
#         return tf.estimator.EstimatorSpec(mode=mode, loss=loss, train_op=train_op)
#
#     # Add evaluation metrics (for EVAL mode)
#     eval_metric_ops = {
#         "accuracy": tf.metrics.accuracy(labels=labels, predictions=predictions["classes"])
#     }
#     return tf.estimator.EstimatorSpec(mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)
#
#
# def _load_training_data(base_dir):
#     x_train = np.load(os.path.join(base_dir, "train_data.npy"))
#     y_train = np.load(os.path.join(base_dir, "train_labels.npy"))
#     return x_train, y_train
#
#
# def _load_testing_data(base_dir):
#     x_test = np.load(os.path.join(base_dir, "eval_data.npy"))
#     y_test = np.load(os.path.join(base_dir, "eval_labels.npy"))
#     return x_test, y_test
#
#
# def _parse_args():
#
#     parser = argparse.ArgumentParser()
#
#     # Data, model, and output directories
#     # model_dir is always passed in from SageMaker. By default this is a S3 path under the default bucket.
#     parser.add_argument("--model_dir", type=str)
#     parser.add_argument("--sm-model-dir", type=str, default=os.environ.get("SM_MODEL_DIR"))
#     parser.add_argument("--train", type=str, default=os.environ.get("SM_CHANNEL_TRAINING"))
#     parser.add_argument("--hosts", type=list, default=json.loads(os.environ.get("SM_HOSTS")))
#     parser.add_argument("--current-host", type=str, default=os.environ.get("SM_CURRENT_HOST"))
#
#     return parser.parse_known_args()
#
#
# def serving_input_fn():
#     inputs = {"x": tf.placeholder(tf.float32, [None, 784])}
#     return tf.estimator.export.ServingInputReceiver(inputs, inputs)
#
#
# if __name__ == "__main__":
#     args, unknown = _parse_args()
#
#     train_data, train_labels = _load_training_data(args.train)
#     eval_data, eval_labels = _load_testing_data(args.train)
#
#     # Create the Estimator
#     mnist_classifier = tf.estimator.Estimator(model_fn=cnn_model_fn, model_dir=args.model_dir)
#
#     # Set up logging for predictions
#     # Log the values in the "Softmax" tensor with label "probabilities"
#     tensors_to_log = {"probabilities": "softmax_tensor"}
#     logging_hook = tf.train.LoggingTensorHook(tensors=tensors_to_log, every_n_iter=50)
#
#     # Train the model
#     train_input_fn = tf.estimator.inputs.numpy_input_fn(
#         x={"x": train_data}, y=train_labels, batch_size=100, num_epochs=None, shuffle=True
#     )
#
#     # Evaluate the model and print results
#     eval_input_fn = tf.estimator.inputs.numpy_input_fn(
#         x={"x": eval_data}, y=eval_labels, num_epochs=1, shuffle=False
#     )
#
#     train_spec = tf.estimator.TrainSpec(train_input_fn, max_steps=20000)
#     eval_spec = tf.estimator.EvalSpec(eval_input_fn)
#     tf.estimator.train_and_evaluate(mnist_classifier, train_spec, eval_spec)
#
#     if args.current_host == args.hosts[0]:
#         mnist_classifier.export_savedmodel(args.sm_model_dir, serving_input_fn)
# # Copyright 2019 Amazon.com, Inc. or its affiliates. All Rights Reserved.
# #
# # Licensed under the Apache License, Version 2.0 (the "License"). You
# # may not use this file except in compliance with the License. A copy of
# # the License is located at
# #
# #     http://aws.amazon.com/apache2.0/
# #
# # or in the "license" file accompanying this file. This file is
# # distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF
# # ANY KIND, either express or implied. See the License for the specific
# # language governing permissions and limitations under the License.import tensorflow as tf
#
# import argparse
# import json
# import os
#
# import numpy as np
# import tensorflow as tf
#
#
# def model(x_train, y_train, x_test, y_test):
#     """Generate a simple model"""
#     model = tf.keras.models.Sequential(
#         [
#             tf.keras.layers.Flatten(),
#             tf.keras.layers.Dense(1024, activation=tf.nn.relu),
#             tf.keras.layers.Dropout(0.4),
#             tf.keras.layers.Dense(10, activation=tf.nn.softmax),
#         ]
#     )
#
#     model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
#     model.fit(x_train, y_train)
#     model.evaluate(x_test, y_test)
#
#     return model
#
#
# def _load_training_data(base_dir):
#     """Load MNIST training data"""
#     x_train = np.load(os.path.join(base_dir, "train_data.npy"))
#     y_train = np.load(os.path.join(base_dir, "train_labels.npy"))
#     return x_train, y_train
#
#
# def _load_testing_data(base_dir):
#     """Load MNIST testing data"""
#     x_test = np.load(os.path.join(base_dir, "eval_data.npy"))
#     y_test = np.load(os.path.join(base_dir, "eval_labels.npy"))
#     return x_test, y_test
#
#
# def _parse_args():
#     parser = argparse.ArgumentParser()
#
#     # Data, model, and output directories
#     # model_dir is always passed in from SageMaker. By default this is a S3 path under the default bucket.
#     parser.add_argument("--model_dir", type=str)
#     parser.add_argument("--sm-model-dir", type=str, default=os.environ.get("SM_MODEL_DIR"))
#     parser.add_argument("--train", type=str, default=os.environ.get("SM_CHANNEL_TRAINING"))
#     parser.add_argument("--hosts", type=list, default=json.loads(os.environ.get("SM_HOSTS")))
#     parser.add_argument("--current-host", type=str, default=os.environ.get("SM_CURRENT_HOST"))
#
#     return parser.parse_known_args()
#
#
# if __name__ == "__main__":
#     args, unknown = _parse_args()
#
#     train_data, train_labels = _load_training_data(args.train)
#     eval_data, eval_labels = _load_testing_data(args.train)
#
#     mnist_classifier = model(train_data, train_labels, eval_data, eval_labels)
#
#     if args.current_host == args.hosts[0]:
#         # save model to an S3 directory with version number '00000001' in Tensorflow SavedModel Format
#         # To export the model as h5 format use model.save('my_model.h5')
#         mnist_classifier.save(os.path.join(args.sm_model_dir, "000000001"))

# %% [markdown]
# # Create a training job using the `TensorFlow` estimator
#
# The `sagemaker.tensorflow.TensorFlow` estimator handles locating the script mode container, uploading your script to a S3 location and creating a SageMaker training job. Let's call out a couple important parameters here:
#
# * `py_version` is set to `'py3'` to indicate that we are using script mode since legacy mode supports only Python 2. Though Python 2 will be deprecated soon, you can use script mode with Python 2 by setting `py_version` to `'py2'` and `script_mode` to `True`.
#
# * `distributions` is used to configure the distributed training setup. It's required only if you are doing distributed training either across a cluster of instances or across multiple GPUs. Here we are using parameter servers as the distributed training schema. SageMaker training jobs run on homogeneous clusters. To make parameter server more performant in the SageMaker setup, we run a parameter server on every instance in the cluster, so there is no need to specify the number of parameter servers to launch. Script mode also supports distributed training with [Horovod](https://github.com/horovod/horovod). You can find the full documentation on how to configure `distributions` [here](https://github.com/aws/sagemaker-python-sdk/tree/master/src/sagemaker/tensorflow#distributed-training).

# %%
from sagemaker.tensorflow import TensorFlow


mnist_estimator = TensorFlow(
    entry_point="mnist.py",
    role=role,
    instance_count=2,
    instance_type="ml.p3.2xlarge",
    framework_version="1.15.2",
    py_version="py3",
    distribution={"parameter_server": {"enabled": True}},
)

# %% [markdown]
# You can also initiate an estimator to train with TensorFlow 2.1 script. The only things that you will need to change are the script name and ``framewotk_version``

# %%
mnist_estimator2 = TensorFlow(
    entry_point="mnist-2.py",
    role=role,
    instance_count=2,
    instance_type="ml.p3.2xlarge",
    framework_version="2.1.0",
    py_version="py3",
    distribution={"parameter_server": {"enabled": True}},
)

# %% [markdown]
# ## Calling ``fit``
#
# To start a training job, we call `estimator.fit(training_data_uri)`.
#
# An S3 location is used here as the input. `fit` creates a default channel named `'training'`, which points to this S3 location. In the training script we can then access the training data from the location stored in `SM_CHANNEL_TRAINING`. `fit` accepts a couple other types of input as well. See the API doc [here](https://sagemaker.readthedocs.io/en/stable/estimators.html#sagemaker.estimator.EstimatorBase.fit) for details.
#
# When training starts, the TensorFlow container executes mnist.py, passing `hyperparameters` and `model_dir` from the estimator as script arguments. Because we didn't define either in this example, no hyperparameters are passed, and `model_dir` defaults to `s3://<DEFAULT_BUCKET>/<TRAINING_JOB_NAME>`, so the script execution is as follows:
# ```bash
# python mnist.py --model_dir s3://<DEFAULT_BUCKET>/<TRAINING_JOB_NAME>
# ```
# When training is complete, the training job will upload the saved model for TensorFlow serving.

# %%
import pandas as pd
import numpy as np

# %%
# !aws s3 cp $training_data_uri/train_labels.npy .
# Out:
# download: s3://sagemaker-sample-data-us-west-2/tensorflow/mnist/train_labels.npy to ./train_labels.npy

# %%
np.load("train_labels.npy")
# Out:
# array([7, 3, 4, ..., 5, 6, 8], dtype=int32)

# %%
mnist_estimator.fit(training_data_uri)
# Out:
# 2021-07-17 02:58:16 Starting - Starting the training job...
# 2021-07-17 02:58:40 Starting - Launching requested ML instancesProfilerReport-1626490696: InProgress
# ......
# 2021-07-17 02:59:40 Starting - Preparing the instances for training......
# 2021-07-17 03:00:40 Downloading - Downloading input data...
# 2021-07-17 03:01:01 Training - Downloading the training image.....WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# 2021-07-17 03:01:55,713 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-07-17 03:01:55,974 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-07-17 03:01:55,975 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2021-07-17 03:01:55,975 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:99: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2021-07-17 03:01:55,975 tensorflow   WARNING  From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:99: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:101: The name tf.train.Server is deprecated. Please use tf.distribute.Server instead.
#
# 2021-07-17 03:01:55,975 tensorflow   WARNING  From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:101: The name tf.train.Server is deprecated. Please use tf.distribute.Server instead.
#
# 2021-07-17 03:01:56,833 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2021-07-17 03:01:58,467 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tensorflow-training-2021-07-17-02-58-16-149",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model"}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2021-07-17-02-58-16-149","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "master"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 mnist.py --model_dir s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model
#
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From mnist.py:156: The name tf.train.LoggingTensorHook is deprecated. Please use tf.estimator.LoggingTensorHook instead.
#
# WARNING:tensorflow:From mnist.py:159: The name tf.estimator.inputs.numpy_input_fn is deprecated. Please use tf.compat.v1.estimator.inputs.numpy_input_fn instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From mnist.py:41: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From mnist.py:41: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From mnist.py:48: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From mnist.py:48: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From mnist.py:74: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From mnist.py:74: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From mnist.py:78: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From mnist.py:78: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From mnist.py:97: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From mnist.py:97: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From mnist.py:101: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From mnist.py:101: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From mnist.py:102: The name tf.train.get_global_step is deprecated. Please use tf.compat.v1.train.get_global_step instead.
#
# WARNING:tensorflow:From mnist.py:102: The name tf.train.get_global_step is deprecated. Please use tf.compat.v1.train.get_global_step instead.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:888: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:888: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
#
# 2021-07-17 03:02:01 Training - Training image download completed. Training in progress.WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# 2021-07-17 03:02:01,689 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-07-17 03:02:01,998 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-07-17 03:02:01,998 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2021-07-17 03:02:01,999 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:99: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2021-07-17 03:02:01,999 tensorflow   WARNING  From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:99: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:101: The name tf.train.Server is deprecated. Please use tf.distribute.Server instead.
#
# 2021-07-17 03:02:01,999 tensorflow   WARNING  From /usr/local/lib/python3.6/dist-packages/sagemaker_tensorflow_container/training.py:101: The name tf.train.Server is deprecated. Please use tf.distribute.Server instead.
#
# 2021-07-17 03:02:02,811 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2021-07-17 03:02:03,074 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "tensorflow-training-2021-07-17-02-58-16-149",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/source/sourcedir.tar.gz",
#     "module_name": "mnist",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model"}
# SM_USER_ENTRY_POINT=mnist.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=mnist
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"tensorflow-training-2021-07-17-02-58-16-149","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/source/sourcedir.tar.gz","module_name":"mnist","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"mnist.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "worker"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 mnist.py --model_dir s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model
#
#
# INFO:tensorflow:Saving checkpoints for 0 into s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 0 into s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/__init__.py:1473: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.
#
# WARNING:tensorflow:From mnist.py:156: The name tf.train.LoggingTensorHook is deprecated. Please use tf.estimator.LoggingTensorHook instead.
#
# WARNING:tensorflow:From mnist.py:159: The name tf.estimator.inputs.numpy_input_fn is deprecated. Please use tf.compat.v1.estimator.inputs.numpy_input_fn instead.
#
# INFO:tensorflow:loss = 2.311854, step = 0
# INFO:tensorflow:loss = 2.311854, step = 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From mnist.py:41: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From mnist.py:41: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From mnist.py:48: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From mnist.py:48: max_pooling2d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling2D instead.
# WARNING:tensorflow:From mnist.py:74: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From mnist.py:74: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.Dense instead.
# WARNING:tensorflow:From mnist.py:78: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From mnist.py:78: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.
# WARNING:tensorflow:From mnist.py:97: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From mnist.py:97: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/losses/losses_impl.py:121: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From mnist.py:101: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From mnist.py:101: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From mnist.py:102: The name tf.train.get_global_step is deprecated. Please use tf.compat.v1.train.get_global_step instead.
#
# WARNING:tensorflow:From mnist.py:102: The name tf.train.get_global_step is deprecated. Please use tf.compat.v1.train.get_global_step instead.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:888: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/monitored_session.py:888: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:loss = 2.2739267, step = 100 (5.939 sec)
# INFO:tensorflow:loss = 2.2739267, step = 100 (5.939 sec)
# INFO:tensorflow:loss = 2.2959137, step = 106
# INFO:tensorflow:loss = 2.2959137, step = 106
# INFO:tensorflow:global_step/sec: 43.369
# INFO:tensorflow:global_step/sec: 43.369
# INFO:tensorflow:loss = 2.2567008, step = 274 (5.923 sec)
# INFO:tensorflow:loss = 2.2567008, step = 274 (5.923 sec)
# INFO:tensorflow:loss = 2.2505767, step = 315 (3.620 sec)
# INFO:tensorflow:loss = 2.2505767, step = 315 (3.620 sec)
# INFO:tensorflow:global_step/sec: 45.6842
# INFO:tensorflow:global_step/sec: 45.6842
# INFO:tensorflow:global_step/sec: 46.9838
# INFO:tensorflow:global_step/sec: 46.9838
# INFO:tensorflow:loss = 2.2239566, step = 471 (3.366 sec)
# INFO:tensorflow:loss = 2.2239566, step = 471 (3.366 sec)
# INFO:tensorflow:global_step/sec: 46.6956
# INFO:tensorflow:global_step/sec: 46.6956
# INFO:tensorflow:loss = 2.1813426, step = 552 (5.988 sec)
# INFO:tensorflow:loss = 2.1813426, step = 552 (5.988 sec)
# INFO:tensorflow:loss = 2.1539724, step = 626 (3.326 sec)
# INFO:tensorflow:loss = 2.1539724, step = 626 (3.326 sec)
# INFO:tensorflow:global_step/sec: 46.7718
# INFO:tensorflow:global_step/sec: 46.7718
# INFO:tensorflow:global_step/sec: 46.612
# INFO:tensorflow:global_step/sec: 46.612
# INFO:tensorflow:loss = 2.1023822, step = 782 (3.331 sec)
# INFO:tensorflow:loss = 2.1023822, step = 782 (3.331 sec)
# INFO:tensorflow:global_step/sec: 46.4652
# INFO:tensorflow:global_step/sec: 46.4652
# INFO:tensorflow:loss = 2.1204362, step = 832 (6.015 sec)
# INFO:tensorflow:loss = 2.1204362, step = 832 (6.015 sec)
# INFO:tensorflow:loss = 2.0751565, step = 937 (3.354 sec)
# INFO:tensorflow:loss = 2.0751565, step = 937 (3.354 sec)
# INFO:tensorflow:global_step/sec: 46.3042
# INFO:tensorflow:global_step/sec: 46.3042
# INFO:tensorflow:global_step/sec: 46.9075
# INFO:tensorflow:global_step/sec: 46.9075
# INFO:tensorflow:loss = 1.9076297, step = 1094 (3.398 sec)
# INFO:tensorflow:loss = 1.9076297, step = 1094 (3.398 sec)
# INFO:tensorflow:loss = 1.8579477, step = 1109 (5.995 sec)
# INFO:tensorflow:loss = 1.8579477, step = 1109 (5.995 sec)
# INFO:tensorflow:global_step/sec: 45.876
# INFO:tensorflow:global_step/sec: 45.876
# INFO:tensorflow:loss = 1.7142502, step = 1249 (3.326 sec)
# INFO:tensorflow:loss = 1.7142502, step = 1249 (3.326 sec)
# INFO:tensorflow:global_step/sec: 46.1662
# INFO:tensorflow:global_step/sec: 46.1662
# INFO:tensorflow:global_step/sec: 44.0577
# INFO:tensorflow:global_step/sec: 44.0577
# INFO:tensorflow:loss = 1.5151917, step = 1407 (3.576 sec)
# INFO:tensorflow:loss = 1.5151917, step = 1407 (3.576 sec)
# INFO:tensorflow:loss = 1.5437106, step = 1387 (6.140 sec)
# INFO:tensorflow:loss = 1.5437106, step = 1387 (6.140 sec)
# INFO:tensorflow:global_step/sec: 44.8
# INFO:tensorflow:global_step/sec: 44.8
# INFO:tensorflow:loss = 1.2524545, step = 1562 (3.440 sec)
# INFO:tensorflow:loss = 1.2524545, step = 1562 (3.440 sec)
# INFO:tensorflow:global_step/sec: 45.0812
# INFO:tensorflow:global_step/sec: 45.0812
# INFO:tensorflow:loss = 1.1257752, step = 1665 (6.136 sec)
# INFO:tensorflow:loss = 1.1257752, step = 1665 (6.136 sec)
# INFO:tensorflow:global_step/sec: 45.4041
# INFO:tensorflow:global_step/sec: 45.4041
# INFO:tensorflow:loss = 0.94264925, step = 1719 (3.478 sec)
# INFO:tensorflow:loss = 0.94264925, step = 1719 (3.478 sec)
# INFO:tensorflow:global_step/sec: 44.0196
# INFO:tensorflow:global_step/sec: 44.0196
# INFO:tensorflow:global_step/sec: 44.1408
# INFO:tensorflow:global_step/sec: 44.1408
# INFO:tensorflow:loss = 0.8295473, step = 1878 (3.618 sec)
# INFO:tensorflow:loss = 0.8295473, step = 1878 (3.618 sec)
# INFO:tensorflow:loss = 0.7010477, step = 1936 (6.119 sec)
# INFO:tensorflow:loss = 0.7010477, step = 1936 (6.119 sec)
# INFO:tensorflow:global_step/sec: 44.6855
# INFO:tensorflow:global_step/sec: 44.6855
# INFO:tensorflow:loss = 0.7624152, step = 2035 (3.525 sec)
# INFO:tensorflow:loss = 0.7624152, step = 2035 (3.525 sec)
# INFO:tensorflow:global_step/sec: 43.7476
# INFO:tensorflow:global_step/sec: 43.7476
# INFO:tensorflow:global_step/sec: 42.4095
# INFO:tensorflow:global_step/sec: 42.4095
# INFO:tensorflow:loss = 0.79237753, step = 2195 (3.742 sec)
# INFO:tensorflow:loss = 0.79237753, step = 2195 (3.742 sec)
# INFO:tensorflow:global_step/sec: 43.2932
# INFO:tensorflow:global_step/sec: 43.2932
# INFO:tensorflow:loss = 0.6665072, step = 2354 (3.805 sec)
# INFO:tensorflow:loss = 0.6665072, step = 2354 (3.805 sec)
# INFO:tensorflow:loss = 0.58469445, step = 2208 (6.273 sec)
# INFO:tensorflow:loss = 0.58469445, step = 2208 (6.273 sec)
# INFO:tensorflow:global_step/sec: 41.1957
# INFO:tensorflow:global_step/sec: 41.1957
# INFO:tensorflow:global_step/sec: 42.4493
# INFO:tensorflow:global_step/sec: 42.4493
# INFO:tensorflow:loss = 0.5785989, step = 2479 (6.441 sec)
# INFO:tensorflow:loss = 0.5785989, step = 2479 (6.441 sec)
# INFO:tensorflow:loss = 0.43818247, step = 2511 (3.696 sec)
# INFO:tensorflow:loss = 0.43818247, step = 2511 (3.696 sec)
# INFO:tensorflow:global_step/sec: 42.5443
# INFO:tensorflow:global_step/sec: 42.5443
# INFO:tensorflow:loss = 0.64914453, step = 2667 (3.581 sec)
# INFO:tensorflow:loss = 0.64914453, step = 2667 (3.581 sec)
# INFO:tensorflow:global_step/sec: 43.5041
# INFO:tensorflow:global_step/sec: 43.5041
# INFO:tensorflow:global_step/sec: 43.2694
# INFO:tensorflow:global_step/sec: 43.2694
# INFO:tensorflow:loss = 0.5071137, step = 2757 (6.454 sec)
# INFO:tensorflow:loss = 0.5071137, step = 2757 (6.454 sec)
# INFO:tensorflow:loss = 0.488756, step = 2824 (3.664 sec)
# INFO:tensorflow:loss = 0.488756, step = 2824 (3.664 sec)
# INFO:tensorflow:global_step/sec: 42.1719
# INFO:tensorflow:global_step/sec: 42.1719
# INFO:tensorflow:loss = 0.42403606, step = 2980 (3.653 sec)
# INFO:tensorflow:loss = 0.42403606, step = 2980 (3.653 sec)
# INFO:tensorflow:global_step/sec: 43.2818
# INFO:tensorflow:global_step/sec: 43.2818
# INFO:tensorflow:loss = 0.38257718, step = 3033 (6.427 sec)
# INFO:tensorflow:loss = 0.38257718, step = 3033 (6.427 sec)
# INFO:tensorflow:global_step/sec: 43.6103
# INFO:tensorflow:global_step/sec: 43.6103
# INFO:tensorflow:loss = 0.32266685, step = 3138 (3.627 sec)
# INFO:tensorflow:loss = 0.32266685, step = 3138 (3.627 sec)
# INFO:tensorflow:global_step/sec: 42.6097
# INFO:tensorflow:global_step/sec: 42.6097
# INFO:tensorflow:global_step/sec: 42.2166
# INFO:tensorflow:global_step/sec: 42.2166
# INFO:tensorflow:loss = 0.43802613, step = 3295 (3.711 sec)
# INFO:tensorflow:loss = 0.43802613, step = 3295 (3.711 sec)
# INFO:tensorflow:loss = 0.51911306, step = 3306 (6.401 sec)
# INFO:tensorflow:loss = 0.51911306, step = 3306 (6.401 sec)
# INFO:tensorflow:global_step/sec: 42.6046
# INFO:tensorflow:global_step/sec: 42.6046
# INFO:tensorflow:loss = 0.40066135, step = 3454 (3.734 sec)
# INFO:tensorflow:loss = 0.40066135, step = 3454 (3.734 sec)
# INFO:tensorflow:global_step/sec: 43.3352
# INFO:tensorflow:global_step/sec: 43.3352
# INFO:tensorflow:global_step/sec: 42.2774
# INFO:tensorflow:global_step/sec: 42.2774
# INFO:tensorflow:loss = 0.39467734, step = 3610 (3.606 sec)
# INFO:tensorflow:loss = 0.39467734, step = 3610 (3.606 sec)
# INFO:tensorflow:global_step/sec: 44.2359
# INFO:tensorflow:global_step/sec: 44.2359
# INFO:tensorflow:loss = 0.39816487, step = 3582 (6.444 sec)
# INFO:tensorflow:loss = 0.39816487, step = 3582 (6.444 sec)
# INFO:tensorflow:loss = 0.36718202, step = 3766 (3.600 sec)
# INFO:tensorflow:loss = 0.36718202, step = 3766 (3.600 sec)
# INFO:tensorflow:global_step/sec: 42.9998
# INFO:tensorflow:global_step/sec: 42.9998
# INFO:tensorflow:loss = 0.38219047, step = 3857 (6.345 sec)
# INFO:tensorflow:loss = 0.38219047, step = 3857 (6.345 sec)
# INFO:tensorflow:global_step/sec: 42.6099
# INFO:tensorflow:global_step/sec: 42.6099
# INFO:tensorflow:loss = 0.51147693, step = 3924 (3.684 sec)
# INFO:tensorflow:loss = 0.51147693, step = 3924 (3.684 sec)
# INFO:tensorflow:global_step/sec: 43.7732
# INFO:tensorflow:global_step/sec: 43.7732
# INFO:tensorflow:loss = 0.2739482, step = 4080 (3.550 sec)
# INFO:tensorflow:loss = 0.2739482, step = 4080 (3.550 sec)
# INFO:tensorflow:global_step/sec: 43.7417
# INFO:tensorflow:global_step/sec: 43.7417
# INFO:tensorflow:loss = 0.23674385, step = 4135 (6.371 sec)
# INFO:tensorflow:loss = 0.23674385, step = 4135 (6.371 sec)
# INFO:tensorflow:global_step/sec: 42.8908
# INFO:tensorflow:global_step/sec: 42.8908
# INFO:tensorflow:loss = 0.4517882, step = 4237 (3.658 sec)
# INFO:tensorflow:loss = 0.4517882, step = 4237 (3.658 sec)
# INFO:tensorflow:global_step/sec: 44.2232
# INFO:tensorflow:global_step/sec: 44.2232
# INFO:tensorflow:global_step/sec: 43.2177
# INFO:tensorflow:global_step/sec: 43.2177
# INFO:tensorflow:loss = 0.29672703, step = 4394 (3.587 sec)
# INFO:tensorflow:loss = 0.29672703, step = 4394 (3.587 sec)
# INFO:tensorflow:loss = 0.24376166, step = 4409 (6.332 sec)
# INFO:tensorflow:loss = 0.24376166, step = 4409 (6.332 sec)
# INFO:tensorflow:global_step/sec: 43.6975
# INFO:tensorflow:global_step/sec: 43.6975
# INFO:tensorflow:loss = 0.42832592, step = 4551 (3.601 sec)
# INFO:tensorflow:loss = 0.42832592, step = 4551 (3.601 sec)
# INFO:tensorflow:global_step/sec: 42.5885
# INFO:tensorflow:global_step/sec: 42.5885
# INFO:tensorflow:loss = 0.25391135, step = 4679 (6.294 sec)
# INFO:tensorflow:loss = 0.25391135, step = 4679 (6.294 sec)
# INFO:tensorflow:global_step/sec: 41.7403
# INFO:tensorflow:global_step/sec: 41.7403
# INFO:tensorflow:loss = 0.35677218, step = 4713 (3.864 sec)
# INFO:tensorflow:loss = 0.35677218, step = 4713 (3.864 sec)
# INFO:tensorflow:global_step/sec: 42.8722
# INFO:tensorflow:global_step/sec: 42.8722
# INFO:tensorflow:loss = 0.3214064, step = 4871 (3.765 sec)
# INFO:tensorflow:loss = 0.3214064, step = 4871 (3.765 sec)
# INFO:tensorflow:global_step/sec: 40.928
# INFO:tensorflow:global_step/sec: 40.928
# INFO:tensorflow:loss = 0.38790932, step = 4945 (6.423 sec)
# INFO:tensorflow:loss = 0.38790932, step = 4945 (6.423 sec)
# INFO:tensorflow:global_step/sec: 41.4589
# INFO:tensorflow:global_step/sec: 41.4589
# INFO:tensorflow:loss = 0.31558892, step = 5032 (3.868 sec)
# INFO:tensorflow:loss = 0.31558892, step = 5032 (3.868 sec)
# INFO:tensorflow:global_step/sec: 43.0276
# INFO:tensorflow:global_step/sec: 43.0276
# INFO:tensorflow:loss = 0.2608434, step = 5191 (3.816 sec)
# INFO:tensorflow:loss = 0.2608434, step = 5191 (3.816 sec)
# INFO:tensorflow:global_step/sec: 41.0352
# INFO:tensorflow:global_step/sec: 41.0352
# INFO:tensorflow:loss = 0.4145129, step = 5215 (6.379 sec)
# INFO:tensorflow:loss = 0.4145129, step = 5215 (6.379 sec)
# INFO:tensorflow:global_step/sec: 42.9502
# INFO:tensorflow:global_step/sec: 42.9502
# INFO:tensorflow:loss = 0.19961756, step = 5350 (3.736 sec)
# INFO:tensorflow:loss = 0.19961756, step = 5350 (3.736 sec)
# INFO:tensorflow:global_step/sec: 42.3817
# INFO:tensorflow:global_step/sec: 42.3817
# INFO:tensorflow:loss = 0.2627946, step = 5490 (6.357 sec)
# INFO:tensorflow:loss = 0.2627946, step = 5490 (6.357 sec)
# INFO:tensorflow:global_step/sec: 44.6479
# INFO:tensorflow:global_step/sec: 44.6479
# INFO:tensorflow:loss = 0.4141661, step = 5505 (3.519 sec)
# INFO:tensorflow:loss = 0.4141661, step = 5505 (3.519 sec)
# INFO:tensorflow:global_step/sec: 43.3794
# INFO:tensorflow:global_step/sec: 43.3794
# INFO:tensorflow:loss = 0.18561658, step = 5661 (3.602 sec)
# INFO:tensorflow:loss = 0.18561658, step = 5661 (3.602 sec)
# INFO:tensorflow:global_step/sec: 44.1345
# INFO:tensorflow:global_step/sec: 44.1345
# INFO:tensorflow:global_step/sec: 43.9557
# INFO:tensorflow:global_step/sec: 43.9557
# INFO:tensorflow:loss = 0.3121603, step = 5819 (3.541 sec)
# INFO:tensorflow:loss = 0.3121603, step = 5819 (3.541 sec)
# INFO:tensorflow:loss = 0.29218456, step = 5766 (6.327 sec)
# INFO:tensorflow:loss = 0.29218456, step = 5766 (6.327 sec)
# INFO:tensorflow:global_step/sec: 46.0518
# INFO:tensorflow:global_step/sec: 46.0518
# INFO:tensorflow:loss = 0.21373564, step = 5974 (3.397 sec)
# INFO:tensorflow:loss = 0.21373564, step = 5974 (3.397 sec)
# INFO:tensorflow:global_step/sec: 45.0892
# INFO:tensorflow:global_step/sec: 45.0892
# INFO:tensorflow:loss = 0.2545463, step = 6045 (6.171 sec)
# INFO:tensorflow:loss = 0.2545463, step = 6045 (6.171 sec)
# INFO:tensorflow:global_step/sec: 44.958
# INFO:tensorflow:global_step/sec: 44.958
# INFO:tensorflow:loss = 0.26571074, step = 6130 (3.476 sec)
# INFO:tensorflow:loss = 0.26571074, step = 6130 (3.476 sec)
# INFO:tensorflow:global_step/sec: 44.5544
# INFO:tensorflow:global_step/sec: 44.5544
# INFO:tensorflow:loss = 0.23460601, step = 6288 (3.551 sec)
# INFO:tensorflow:loss = 0.23460601, step = 6288 (3.551 sec)
# INFO:tensorflow:global_step/sec: 44.2541
# INFO:tensorflow:global_step/sec: 44.2541
# INFO:tensorflow:loss = 0.30855387, step = 6321 (6.160 sec)
# INFO:tensorflow:loss = 0.30855387, step = 6321 (6.160 sec)
# INFO:tensorflow:global_step/sec: 45.9685
# INFO:tensorflow:global_step/sec: 45.9685
# INFO:tensorflow:loss = 0.22056326, step = 6442 (3.411 sec)
# INFO:tensorflow:loss = 0.22056326, step = 6442 (3.411 sec)
# INFO:tensorflow:global_step/sec: 42.7981
# INFO:tensorflow:global_step/sec: 42.7981
# INFO:tensorflow:loss = 0.2533399, step = 6600 (6.351 sec)
# INFO:tensorflow:loss = 0.2533399, step = 6600 (6.351 sec)
# INFO:tensorflow:loss = 0.22261606, step = 6599 (3.641 sec)
# INFO:tensorflow:loss = 0.22261606, step = 6599 (3.641 sec)
# INFO:tensorflow:global_step/sec: 43.9569
# INFO:tensorflow:global_step/sec: 43.9569
# INFO:tensorflow:global_step/sec: 43.4746
# INFO:tensorflow:global_step/sec: 43.4746
# INFO:tensorflow:loss = 0.18751626, step = 6756 (3.552 sec)
# INFO:tensorflow:loss = 0.18751626, step = 6756 (3.552 sec)
# INFO:tensorflow:global_step/sec: 44.3889
# INFO:tensorflow:global_step/sec: 44.3889
# INFO:tensorflow:loss = 0.3415841, step = 6875 (6.218 sec)
# INFO:tensorflow:loss = 0.3415841, step = 6875 (6.218 sec)
# INFO:tensorflow:loss = 0.28558424, step = 6912 (3.474 sec)
# INFO:tensorflow:loss = 0.28558424, step = 6912 (3.474 sec)
# INFO:tensorflow:global_step/sec: 45.8041
# INFO:tensorflow:global_step/sec: 45.8041
# INFO:tensorflow:global_step/sec: 47.228
# INFO:tensorflow:global_step/sec: 47.228
# INFO:tensorflow:loss = 0.18573743, step = 7066 (3.290 sec)
# INFO:tensorflow:loss = 0.18573743, step = 7066 (3.290 sec)
# INFO:tensorflow:global_step/sec: 46.507
# INFO:tensorflow:global_step/sec: 46.507
# INFO:tensorflow:loss = 0.25175276, step = 7159 (6.068 sec)
# INFO:tensorflow:loss = 0.25175276, step = 7159 (6.068 sec)
# INFO:tensorflow:global_step/sec: 46.2801
# INFO:tensorflow:global_step/sec: 46.2801
# INFO:tensorflow:loss = 0.26388758, step = 7220 (3.309 sec)
# INFO:tensorflow:loss = 0.26388758, step = 7220 (3.309 sec)
# INFO:tensorflow:global_step/sec: 45.7708
# INFO:tensorflow:global_step/sec: 45.7708
# INFO:tensorflow:loss = 0.27886736, step = 7377 (3.482 sec)
# INFO:tensorflow:loss = 0.27886736, step = 7377 (3.482 sec)
# INFO:tensorflow:global_step/sec: 44.6335
# INFO:tensorflow:global_step/sec: 44.6335
# INFO:tensorflow:loss = 0.28434008, step = 7438 (6.137 sec)
# INFO:tensorflow:loss = 0.28434008, step = 7438 (6.137 sec)
# INFO:tensorflow:global_step/sec: 45.1084
# INFO:tensorflow:global_step/sec: 45.1084
# INFO:tensorflow:loss = 0.2263628, step = 7532 (3.424 sec)
# INFO:tensorflow:loss = 0.2263628, step = 7532 (3.424 sec)
# INFO:tensorflow:global_step/sec: 46.2004
# INFO:tensorflow:global_step/sec: 46.2004
# INFO:tensorflow:loss = 0.12350546, step = 7687 (3.313 sec)
# INFO:tensorflow:loss = 0.12350546, step = 7687 (3.313 sec)
# INFO:tensorflow:global_step/sec: 46.8482
# INFO:tensorflow:global_step/sec: 46.8482
# INFO:tensorflow:loss = 0.20274739, step = 7720 (6.106 sec)
# INFO:tensorflow:loss = 0.20274739, step = 7720 (6.106 sec)
# INFO:tensorflow:global_step/sec: 45.6537
# INFO:tensorflow:global_step/sec: 45.6537
# INFO:tensorflow:loss = 0.23281331, step = 7843 (3.448 sec)
# INFO:tensorflow:loss = 0.23281331, step = 7843 (3.448 sec)
# INFO:tensorflow:global_step/sec: 45.1141
# INFO:tensorflow:global_step/sec: 45.1141
# INFO:tensorflow:loss = 0.1930723, step = 8000 (3.418 sec)
# INFO:tensorflow:loss = 0.1930723, step = 8000 (3.418 sec)
# INFO:tensorflow:loss = 0.23484094, step = 7996 (6.064 sec)
# INFO:tensorflow:loss = 0.23484094, step = 7996 (6.064 sec)
# INFO:tensorflow:global_step/sec: 45.7966
# INFO:tensorflow:global_step/sec: 45.7966
# INFO:tensorflow:global_step/sec: 45.7125
# INFO:tensorflow:global_step/sec: 45.7125
# INFO:tensorflow:loss = 0.20220713, step = 8158 (3.474 sec)
# INFO:tensorflow:loss = 0.20220713, step = 8158 (3.474 sec)
# INFO:tensorflow:global_step/sec: 45.0731
# INFO:tensorflow:global_step/sec: 45.0731
# INFO:tensorflow:loss = 0.2750728, step = 8272 (6.080 sec)
# INFO:tensorflow:loss = 0.2750728, step = 8272 (6.080 sec)
# INFO:tensorflow:loss = 0.14352763, step = 8314 (3.443 sec)
# INFO:tensorflow:loss = 0.14352763, step = 8314 (3.443 sec)
# INFO:tensorflow:global_step/sec: 45.166
# INFO:tensorflow:global_step/sec: 45.166
# INFO:tensorflow:global_step/sec: 44.8658
# INFO:tensorflow:global_step/sec: 44.8658
# INFO:tensorflow:loss = 0.2692447, step = 8470 (3.488 sec)
# INFO:tensorflow:loss = 0.2692447, step = 8470 (3.488 sec)
# INFO:tensorflow:global_step/sec: 44.8367
# INFO:tensorflow:global_step/sec: 44.8367
# INFO:tensorflow:global_step/sec: 42.2723
# INFO:tensorflow:global_step/sec: 42.2723
# INFO:tensorflow:loss = 0.24566697, step = 8628 (3.663 sec)
# INFO:tensorflow:loss = 0.24566697, step = 8628 (3.663 sec)
# INFO:tensorflow:loss = 0.32387406, step = 8548 (6.206 sec)
# INFO:tensorflow:loss = 0.32387406, step = 8548 (6.206 sec)
# INFO:tensorflow:global_step/sec: 46.172
# INFO:tensorflow:global_step/sec: 46.172
# INFO:tensorflow:loss = 0.22411136, step = 8783 (3.331 sec)
# INFO:tensorflow:loss = 0.22411136, step = 8783 (3.331 sec)
# INFO:tensorflow:loss = 0.17737322, step = 8825 (6.155 sec)
# INFO:tensorflow:loss = 0.17737322, step = 8825 (6.155 sec)
# INFO:tensorflow:global_step/sec: 45.5072
# INFO:tensorflow:global_step/sec: 45.5072
# INFO:tensorflow:global_step/sec: 44.8685
# INFO:tensorflow:global_step/sec: 44.8685
# INFO:tensorflow:loss = 0.2868468, step = 8941 (3.553 sec)
# INFO:tensorflow:loss = 0.2868468, step = 8941 (3.553 sec)
# INFO:tensorflow:global_step/sec: 44.6105
# INFO:tensorflow:global_step/sec: 44.6105
# INFO:tensorflow:loss = 0.18806459, step = 9099 (6.145 sec)
# INFO:tensorflow:loss = 0.18806459, step = 9099 (6.145 sec)
# INFO:tensorflow:loss = 0.27217644, step = 9098 (3.538 sec)
# INFO:tensorflow:loss = 0.27217644, step = 9098 (3.538 sec)
# INFO:tensorflow:global_step/sec: 43.7314
# INFO:tensorflow:global_step/sec: 43.7314
# INFO:tensorflow:global_step/sec: 45.2226
# INFO:tensorflow:global_step/sec: 45.2226
# INFO:tensorflow:loss = 0.21632549, step = 9256 (3.558 sec)
# INFO:tensorflow:loss = 0.21632549, step = 9256 (3.558 sec)
# INFO:tensorflow:global_step/sec: 44.143
# INFO:tensorflow:global_step/sec: 44.143
# INFO:tensorflow:loss = 0.21575633, step = 9413 (3.543 sec)
# INFO:tensorflow:loss = 0.21575633, step = 9413 (3.543 sec)
# INFO:tensorflow:global_step/sec: 43.7112
# INFO:tensorflow:global_step/sec: 43.7112
# INFO:tensorflow:loss = 0.18613285, step = 9373 (6.199 sec)
# INFO:tensorflow:loss = 0.18613285, step = 9373 (6.199 sec)
# INFO:tensorflow:global_step/sec: 44.9257
# INFO:tensorflow:global_step/sec: 44.9257
# INFO:tensorflow:loss = 0.347874, step = 9570 (3.534 sec)
# INFO:tensorflow:loss = 0.347874, step = 9570 (3.534 sec)
# INFO:tensorflow:global_step/sec: 43.9745
# INFO:tensorflow:global_step/sec: 43.9745
# INFO:tensorflow:loss = 0.09031743, step = 9647 (6.180 sec)
# INFO:tensorflow:loss = 0.09031743, step = 9647 (6.180 sec)
# INFO:tensorflow:loss = 0.2096146, step = 9730 (3.664 sec)
# INFO:tensorflow:loss = 0.2096146, step = 9730 (3.664 sec)
# INFO:tensorflow:global_step/sec: 43.5309
# INFO:tensorflow:global_step/sec: 43.5309
# INFO:tensorflow:global_step/sec: 43.5108
# INFO:tensorflow:global_step/sec: 43.5108
# INFO:tensorflow:loss = 0.19719319, step = 9886 (3.530 sec)
# ...
# INFO:tensorflow:loss = 0.20731442, step = 15452 (6.209 sec)
# INFO:tensorflow:global_step/sec: 44.9834
# INFO:tensorflow:global_step/sec: 44.9834
# INFO:tensorflow:loss = 0.1964356, step = 15523 (3.546 sec)
# INFO:tensorflow:loss = 0.1964356, step = 15523 (3.546 sec)
# INFO:tensorflow:global_step/sec: 41.685
# INFO:tensorflow:global_step/sec: 41.685
# INFO:tensorflow:global_step/sec: 42.9382
# INFO:tensorflow:global_step/sec: 42.9382
# INFO:tensorflow:loss = 0.14580593, step = 15684 (3.799 sec)
# INFO:tensorflow:loss = 0.14580593, step = 15684 (3.799 sec)
# INFO:tensorflow:global_step/sec: 45.2069
# INFO:tensorflow:global_step/sec: 45.2069
# INFO:tensorflow:loss = 0.17388284, step = 15839 (3.393 sec)
# INFO:tensorflow:loss = 0.17388284, step = 15839 (3.393 sec)
# INFO:tensorflow:global_step/sec: 44.693
# INFO:tensorflow:global_step/sec: 44.693
# INFO:tensorflow:loss = 0.08760402, step = 15723 (6.305 sec)
# INFO:tensorflow:loss = 0.08760402, step = 15723 (6.305 sec)
# INFO:tensorflow:global_step/sec: 43.8222
# INFO:tensorflow:global_step/sec: 43.8222
# INFO:tensorflow:loss = 0.25910944, step = 16000 (6.195 sec)
# INFO:tensorflow:loss = 0.25910944, step = 16000 (6.195 sec)
# INFO:tensorflow:loss = 0.13761935, step = 15996 (3.607 sec)
# INFO:tensorflow:loss = 0.13761935, step = 15996 (3.607 sec)
# INFO:tensorflow:global_step/sec: 45.551
# INFO:tensorflow:global_step/sec: 45.551
# INFO:tensorflow:loss = 0.103630096, step = 16152 (3.401 sec)
# INFO:tensorflow:loss = 0.103630096, step = 16152 (3.401 sec)
# INFO:tensorflow:global_step/sec: 45.406
# INFO:tensorflow:global_step/sec: 45.406
# INFO:tensorflow:loss = 0.12210302, step = 16280 (6.117 sec)
# INFO:tensorflow:loss = 0.12210302, step = 16280 (6.117 sec)
# INFO:tensorflow:global_step/sec: 46.3618
# INFO:tensorflow:global_step/sec: 46.3618
# INFO:tensorflow:loss = 0.11036035, step = 16308 (3.423 sec)
# INFO:tensorflow:loss = 0.11036035, step = 16308 (3.423 sec)
# INFO:tensorflow:global_step/sec: 44.9187
# INFO:tensorflow:global_step/sec: 44.9187
# INFO:tensorflow:loss = 0.19441245, step = 16463 (3.494 sec)
# INFO:tensorflow:loss = 0.19441245, step = 16463 (3.494 sec)
# INFO:tensorflow:global_step/sec: 43.7969
# INFO:tensorflow:global_step/sec: 43.7969
# INFO:tensorflow:loss = 0.14949398, step = 16556 (6.247 sec)
# INFO:tensorflow:loss = 0.14949398, step = 16556 (6.247 sec)
# INFO:tensorflow:global_step/sec: 43.7579
# INFO:tensorflow:global_step/sec: 43.7579
# INFO:tensorflow:loss = 0.13499606, step = 16621 (3.627 sec)
# INFO:tensorflow:loss = 0.13499606, step = 16621 (3.627 sec)
# INFO:tensorflow:global_step/sec: 43.3145
# INFO:tensorflow:global_step/sec: 43.3145
# INFO:tensorflow:loss = 0.10228856, step = 16777 (3.486 sec)
# INFO:tensorflow:loss = 0.10228856, step = 16777 (3.486 sec)
# INFO:tensorflow:global_step/sec: 45.1296
# INFO:tensorflow:global_step/sec: 45.1296
# INFO:tensorflow:loss = 0.1806627, step = 16832 (6.276 sec)
# INFO:tensorflow:loss = 0.1806627, step = 16832 (6.276 sec)
# INFO:tensorflow:global_step/sec: 45.26
# INFO:tensorflow:global_step/sec: 45.26
# INFO:tensorflow:loss = 0.20038924, step = 16933 (3.450 sec)
# INFO:tensorflow:loss = 0.20038924, step = 16933 (3.450 sec)
# INFO:tensorflow:global_step/sec: 44.9017
# INFO:tensorflow:global_step/sec: 44.9017
# INFO:tensorflow:loss = 0.24140584, step = 17089 (3.467 sec)
# INFO:tensorflow:loss = 0.24140584, step = 17089 (3.467 sec)
# INFO:tensorflow:global_step/sec: 45.4522
# INFO:tensorflow:global_step/sec: 45.4522
# INFO:tensorflow:loss = 0.13046369, step = 17113 (6.201 sec)
# INFO:tensorflow:loss = 0.13046369, step = 17113 (6.201 sec)
# INFO:tensorflow:global_step/sec: 43.7441
# INFO:tensorflow:global_step/sec: 43.7441
# INFO:tensorflow:loss = 0.17653982, step = 17245 (3.531 sec)
# INFO:tensorflow:loss = 0.17653982, step = 17245 (3.531 sec)
# INFO:tensorflow:global_step/sec: 44.576
# INFO:tensorflow:global_step/sec: 44.576
# INFO:tensorflow:loss = 0.14441869, step = 17392 (6.250 sec)
# INFO:tensorflow:loss = 0.14441869, step = 17392 (6.250 sec)
# INFO:tensorflow:global_step/sec: 45.3292
# INFO:tensorflow:global_step/sec: 45.3292
# INFO:tensorflow:loss = 0.04824901, step = 17401 (3.501 sec)
# INFO:tensorflow:loss = 0.04824901, step = 17401 (3.501 sec)
# INFO:tensorflow:global_step/sec: 43.3034
# INFO:tensorflow:global_step/sec: 43.3034
# INFO:tensorflow:loss = 0.15691866, step = 17557 (3.542 sec)
# INFO:tensorflow:loss = 0.15691866, step = 17557 (3.542 sec)
# INFO:tensorflow:global_step/sec: 45.0978
# INFO:tensorflow:global_step/sec: 45.0978
# INFO:tensorflow:loss = 0.24673262, step = 17670 (6.263 sec)
# INFO:tensorflow:loss = 0.24673262, step = 17670 (6.263 sec)
# INFO:tensorflow:global_step/sec: 44.6298
# INFO:tensorflow:global_step/sec: 44.6298
# INFO:tensorflow:loss = 0.0692292, step = 17713 (3.490 sec)
# INFO:tensorflow:loss = 0.0692292, step = 17713 (3.490 sec)
# INFO:tensorflow:global_step/sec: 45.3798
# INFO:tensorflow:global_step/sec: 45.3798
# INFO:tensorflow:loss = 0.15879603, step = 17867 (3.312 sec)
# INFO:tensorflow:loss = 0.15879603, step = 17867 (3.312 sec)
# INFO:tensorflow:global_step/sec: 45.9812
# INFO:tensorflow:global_step/sec: 45.9812
# INFO:tensorflow:loss = 0.17688099, step = 17953 (6.181 sec)
# INFO:tensorflow:loss = 0.17688099, step = 17953 (6.181 sec)
# INFO:tensorflow:global_step/sec: 46.2052
# INFO:tensorflow:global_step/sec: 46.2052
# INFO:tensorflow:loss = 0.060790233, step = 18023 (3.460 sec)
# INFO:tensorflow:loss = 0.060790233, step = 18023 (3.460 sec)
# INFO:tensorflow:global_step/sec: 45.0881
# INFO:tensorflow:global_step/sec: 45.0881
# INFO:tensorflow:loss = 0.14827755, step = 18179 (3.429 sec)
# INFO:tensorflow:loss = 0.14827755, step = 18179 (3.429 sec)
# INFO:tensorflow:global_step/sec: 45.0419
# INFO:tensorflow:global_step/sec: 45.0419
# INFO:tensorflow:loss = 0.061751615, step = 18233 (6.149 sec)
# INFO:tensorflow:loss = 0.061751615, step = 18233 (6.149 sec)
# INFO:tensorflow:global_step/sec: 47.3692
# INFO:tensorflow:global_step/sec: 47.3692
# INFO:tensorflow:loss = 0.14441356, step = 18333 (3.274 sec)
# INFO:tensorflow:loss = 0.14441356, step = 18333 (3.274 sec)
# INFO:tensorflow:global_step/sec: 47.1941
# INFO:tensorflow:global_step/sec: 47.1941
# INFO:tensorflow:loss = 0.1457639, step = 18487 (3.269 sec)
# INFO:tensorflow:loss = 0.1457639, step = 18487 (3.269 sec)
# INFO:tensorflow:global_step/sec: 47.4473
# INFO:tensorflow:global_step/sec: 47.4473
# INFO:tensorflow:loss = 0.07289936, step = 18517 (6.023 sec)
# INFO:tensorflow:loss = 0.07289936, step = 18517 (6.023 sec)
# INFO:tensorflow:global_step/sec: 48.2179
# INFO:tensorflow:global_step/sec: 48.2179
# INFO:tensorflow:loss = 0.13076477, step = 18640 (3.166 sec)
# INFO:tensorflow:loss = 0.13076477, step = 18640 (3.166 sec)
# INFO:tensorflow:global_step/sec: 47.233
# INFO:tensorflow:global_step/sec: 47.233
# INFO:tensorflow:loss = 0.12324557, step = 18795 (3.385 sec)
# INFO:tensorflow:loss = 0.12324557, step = 18795 (3.385 sec)
# INFO:tensorflow:global_step/sec: 45.0569
# INFO:tensorflow:global_step/sec: 45.0569
# INFO:tensorflow:loss = 0.027045343, step = 18803 (6.115 sec)
# INFO:tensorflow:loss = 0.027045343, step = 18803 (6.115 sec)
# INFO:tensorflow:global_step/sec: 46.716
# INFO:tensorflow:global_step/sec: 46.716
# INFO:tensorflow:loss = 0.15427488, step = 18949 (3.352 sec)
# INFO:tensorflow:loss = 0.15427488, step = 18949 (3.352 sec)
# INFO:tensorflow:global_step/sec: 45.3533
# INFO:tensorflow:global_step/sec: 45.3533
# INFO:tensorflow:loss = 0.13535665, step = 19085 (6.161 sec)
# INFO:tensorflow:loss = 0.13535665, step = 19085 (6.161 sec)
# INFO:tensorflow:loss = 0.24724574, step = 19104 (3.403 sec)
# INFO:tensorflow:loss = 0.24724574, step = 19104 (3.403 sec)
# INFO:tensorflow:global_step/sec: 45.5128
# INFO:tensorflow:global_step/sec: 45.5128
# INFO:tensorflow:global_step/sec: 44.861
# INFO:tensorflow:global_step/sec: 44.861
# INFO:tensorflow:loss = 0.118007526, step = 19259 (3.422 sec)
# INFO:tensorflow:loss = 0.118007526, step = 19259 (3.422 sec)
# INFO:tensorflow:global_step/sec: 45.0742
# INFO:tensorflow:global_step/sec: 45.0742
# INFO:tensorflow:loss = 0.16599412, step = 19369 (6.276 sec)
# INFO:tensorflow:loss = 0.16599412, step = 19369 (6.276 sec)
# INFO:tensorflow:global_step/sec: 45.6138
# INFO:tensorflow:global_step/sec: 45.6138
# INFO:tensorflow:loss = 0.15128087, step = 19413 (3.422 sec)
# INFO:tensorflow:loss = 0.15128087, step = 19413 (3.422 sec)
# INFO:tensorflow:global_step/sec: 45.7848
# INFO:tensorflow:global_step/sec: 45.7848
# INFO:tensorflow:loss = 0.10794627, step = 19567 (3.331 sec)
# INFO:tensorflow:loss = 0.10794627, step = 19567 (3.331 sec)
# INFO:tensorflow:global_step/sec: 47.7569
# INFO:tensorflow:global_step/sec: 47.7569
# INFO:tensorflow:loss = 0.122495376, step = 19655 (6.104 sec)
# INFO:tensorflow:loss = 0.122495376, step = 19655 (6.104 sec)
# INFO:tensorflow:global_step/sec: 47.5544
# INFO:tensorflow:global_step/sec: 47.5544
# INFO:tensorflow:loss = 0.046189915, step = 19720 (3.210 sec)
# INFO:tensorflow:loss = 0.046189915, step = 19720 (3.210 sec)
# INFO:tensorflow:global_step/sec: 44.4326
# INFO:tensorflow:global_step/sec: 44.4326
# INFO:tensorflow:loss = 0.08403523, step = 19876 (3.502 sec)
# INFO:tensorflow:loss = 0.08403523, step = 19876 (3.502 sec)
# INFO:tensorflow:global_step/sec: 44.3293
# INFO:tensorflow:global_step/sec: 44.3293
# INFO:tensorflow:loss = 0.2640338, step = 19935 (6.237 sec)
# INFO:tensorflow:loss = 0.2640338, step = 19935 (6.237 sec)
# INFO:tensorflow:Saving checkpoints for 20002 into s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 20002 into s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.14981695.
# INFO:tensorflow:Loss for final step: 0.14981695.
# 2021-07-17 03:09:46,464 sagemaker_tensorflow_container.training INFO     master algo-1 is still up, waiting for it to exit
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From mnist.py:107: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# WARNING:tensorflow:From mnist.py:107: The name tf.metrics.accuracy is deprecated. Please use tf.compat.v1.metrics.accuracy instead.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2021-07-17T03:09:48Z
# INFO:tensorflow:Starting evaluation at 2021-07-17T03:09:48Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model/model.ckpt-20002
# INFO:tensorflow:Restoring parameters from s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model/model.ckpt-20002
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [40/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [50/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [60/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Evaluation [70/100]
# INFO:tensorflow:Finished evaluation at 2021-07-17-03:09:48
# INFO:tensorflow:Finished evaluation at 2021-07-17-03:09:48
# INFO:tensorflow:Saving dict for global step 20002: accuracy = 0.9698, global_step = 20002, loss = 0.099218465
# INFO:tensorflow:Saving dict for global step 20002: accuracy = 0.9698, global_step = 20002, loss = 0.099218465
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20002: s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model/model.ckpt-20002
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20002: s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model/model.ckpt-20002
# INFO:tensorflow:Loss for final step: 0.10105783.
# INFO:tensorflow:Loss for final step: 0.10105783.
# WARNING:tensorflow:From mnist.py:173: Estimator.export_savedmodel (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function has been renamed, use `export_saved_model` instead.
# WARNING:tensorflow:From mnist.py:173: Estimator.export_savedmodel (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function has been renamed, use `export_saved_model` instead.
# WARNING:tensorflow:From mnist.py:140: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From mnist.py:140: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model/model.ckpt-20002
# INFO:tensorflow:Restoring parameters from s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/model/model.ckpt-20002
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: /opt/ml/model/temp-1626491389/saved_model.pb
# INFO:tensorflow:SavedModel written to: /opt/ml/model/temp-1626491389/saved_model.pb
# 2021-07-17 03:09:51,197 sagemaker-containers INFO     Reporting training SUCCESS
# 2021-07-17 03:11:04,299 sagemaker_tensorflow_container.training INFO     master algo-1 is down, stopping parameter server
# 2021-07-17 03:11:04,299 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-07-17 03:11:04,300 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-07-17 03:11:59 Uploading - Uploading generated training model
# 2021-07-17 03:12:24 Completed - Training job completed
# ProfilerReport-1626490696: IssuesFound
# Training seconds: 1382
# Billable seconds: 1382

# %% [markdown]
# Calling fit to train a model with TensorFlow 2.1 script.

# %%
mnist_estimator2.fit(training_data_uri)
# Out:
# 2021-07-17 03:12:43 Starting - Starting the training job...
# 2021-07-17 03:13:06 Starting - Launching requested ML instancesProfilerReport-1626491563: InProgress
# ...
# 2021-07-17 03:13:26 Starting - Insufficient capacity error from EC2 while launching instances, retrying!...
# 2021-07-17 03:14:13 Starting - Preparing the instances for training.........
# 2021-07-17 03:15:44 Downloading - Downloading input data...
# 2021-07-17 03:16:07 Training - Downloading the training image......
# 2021-07-17 03:17:08 Training - Training image download completed. Training in progress..2021-07-17 03:17:12,394 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-07-17 03:17:12,660 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-07-17 03:17:12,660 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2021-07-17 03:17:12,661 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-07-17 03:17:13,419 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2021-07-17 03:17:13,625 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-2",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": false,
#     "job_name": "tensorflow-training-2021-07-17-03-12-43-276",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/source/sourcedir.tar.gz",
#     "module_name": "mnist-2",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-2",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist-2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model"}
# SM_USER_ENTRY_POINT=mnist-2.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-2
# SM_MODULE_NAME=mnist-2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-2","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":false,"job_name":"tensorflow-training-2021-07-17-03-12-43-276","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/source/sourcedir.tar.gz","module_name":"mnist-2","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-2","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"mnist-2.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "worker"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 mnist-2.py --model_dir s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model
#
#
# 2021-07-17 03:17:11,443 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-07-17 03:17:11,686 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-07-17 03:17:11,686 sagemaker_tensorflow_container.training INFO     Launching parameter server process
# 2021-07-17 03:17:11,686 sagemaker_tensorflow_container.training INFO     Running distributed training job with parameter servers
# 2021-07-17 03:17:12,477 sagemaker_tensorflow_container.training INFO     Launching worker process
# 2021-07-17 03:17:12,707 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_parameter_server_enabled": true
#     },
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1",
#         "algo-2"
#     ],
#     "hyperparameters": {
#         "model_dir": "s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tensorflow-training-2021-07-17-03-12-43-276",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/source/sourcedir.tar.gz",
#     "module_name": "mnist-2",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1",
#             "algo-2"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "mnist-2.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1","algo-2"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"model_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model"}
# SM_USER_ENTRY_POINT=mnist-2.py
# SM_FRAMEWORK_PARAMS={"sagemaker_parameter_server_enabled":true}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=mnist-2
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_parameter_server_enabled":true},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1","algo-2"],"hyperparameters":{"model_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tensorflow-training-2021-07-17-03-12-43-276","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/source/sourcedir.tar.gz","module_name":"mnist-2","network_interface_name":"eth0","num_cpus":8,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1","algo-2"],"network_interface_name":"eth0"},"user_entry_point":"mnist-2.py"}
# SM_USER_ARGS=["--model_dir","s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_MODEL_DIR=s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model
# TF_CONFIG={"cluster": {"master": ["algo-1:2222"], "ps": ["algo-1:2223", "algo-2:2223"], "worker": ["algo-2:2222"]}, "environment": "cloud", "task": {"index": 0, "type": "master"}}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 mnist-2.py --model_dir s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-03-12-43-276/model
#
#
# Train on 55000 samples
# Train on 55000 samples
# #015   32/55000 [..............................] - ETA: 26:36 - loss: 2.3869 - accuracy: 0.1250#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  736/55000 [..............................] - ETA: 1:12 - loss: 1.2673 - accuracy: 0.6182 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1472/55000 [..............................] - ETA: 37s - loss: 0.9235 - accuracy: 0.7194 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2208/55000 [>.............................] - ETA: 25s - loss: 0.7946 - accuracy: 0.7582#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2944/55000 [>.............................] - ETA: 20s - loss: 0.7007 - accuracy: 0.7867#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3680/55000 [=>............................] - ETA: 16s - loss: 0.6453 - accuracy: 0.8043#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4416/55000 [=>............................] - ETA: 14s - loss: 0.5968 - accuracy: 0.8202#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5152/55000 [=>............................] - ETA: 12s - loss: 0.5723 - accuracy: 0.8280#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5888/55000 [==>...........................] - ETA: 11s - loss: 0.5416 - accuracy: 0.8380#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# #015   32/10000 [..............................] - ETA: 22s - loss: 0.0332 - accuracy: 0.9688#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  992/10000 [=>............................] - ETA: 1s - loss: 0.1296 - accuracy: 0.9607 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1952/10000 [====>.........................] - ETA: 0s - loss: 0.1628 - accuracy: 0.9508#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2912/10000 [=======>......................] - ETA: 0s - loss: 0.1661 - accuracy: 0.9488#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3840/10000 [==========>...................] - ETA: 0s - loss: 0.1640 - accuracy: 0.9503#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4800/10000 [=============>................] - ETA: 0s - loss: 0.1622 - accuracy: 0.9492#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5760/10000 [================>.............] - ETA: 0s - loss: 0.1540 - accuracy: 0.9524#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 6720/10000 [===================>..........] - ETA: 0s - loss: 0.1470 - accuracy: 0.9548#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 7680/10000 [======================>.......] - ETA: 0s - loss: 0.1343 - accuracy: 0.9587#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# 2021-07-17 03:17:22.896115: W tensorflow/python/util/util.cc:319] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# #015   32/55000 [..............................] - ETA: 28:31 - loss: 2.3871 - accuracy: 0.0938#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  736/55000 [..............................] - ETA: 1:17 - loss: 1.2811 - accuracy: 0.6155 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1472/55000 [..............................] - ETA: 39s - loss: 0.9297 - accuracy: 0.7221 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2208/55000 [>.............................] - ETA: 27s - loss: 0.7709 - accuracy: 0.7681#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2944/55000 [>.............................] - ETA: 21s - loss: 0.6714 - accuracy: 0.7972#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3680/55000 [=>............................] - ETA: 17s - loss: 0.6062 - accuracy: 0.8188#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4384/55000 [=>............................] - ETA: 15s - loss: 0.5752 - accuracy: 0.8292#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5088/55000 [=>............................] - ETA: 13s - loss: 0.5512 - accuracy: 0.8377#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5824/55000 [==>...........................] - ETA: 11s - loss: 0.5264 - accuracy: 0.8453#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# #015   32/10000 [..............................] - ETA: 24s - loss: 0.0263 - accuracy: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  992/10000 [=>............................] - ETA: 1s - loss: 0.1137 - accuracy: 0.9587 #010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 1952/10000 [====>.........................] - ETA: 0s - loss: 0.1492 - accuracy: 0.9524#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 2912/10000 [=======>......................] - ETA: 0s - loss: 0.1566 - accuracy: 0.9509#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 3872/10000 [==========>...................] - ETA: 0s - loss: 0.1532 - accuracy: 0.9522#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 4832/10000 [=============>................] - ETA: 0s - loss: 0.1517 - accuracy: 0.9526#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 5760/10000 [================>.............] - ETA: 0s - loss: 0.1409 - accuracy: 0.9563#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 6720/10000 [===================>..........] - ETA: 0s - loss: 0.1361 - accuracy: 0.9577#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 7680/10000 [======================>.......] - ETA: 0s - loss: 0.1241 - accuracy: 0.9616#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# INFO:tensorflow:Assets written to: /opt/ml/model/000000001/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/000000001/assets
# 2021-07-17 03:17:23,640 sagemaker-containers INFO     Reporting training SUCCESS
# 2021-07-17 03:17:24,200 sagemaker_tensorflow_container.training INFO     master algo-1 is down, stopping parameter server
# 2021-07-17 03:17:24,201 sagemaker_tensorflow_container.training WARNING  No model artifact is saved under path /opt/ml/model. Your training job will not save any model files to S3.
# For details of how to construct your training script see:
# https://sagemaker.readthedocs.io/en/stable/using_tf.html#adapting-your-local-tensorflow-script
# 2021-07-17 03:17:24,201 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2021-07-17 03:17:47 Uploading - Uploading generated training model
# 2021-07-17 03:17:47 Completed - Training job completed
# ProfilerReport-1626491563: NoIssuesFound
# Training seconds: 228
# Billable seconds: 228

# %% [markdown]
# # Deploy the trained model to an endpoint
#
# The `deploy()` method creates a SageMaker model, which is then deployed to an endpoint to serve prediction requests in real time. We will use the TensorFlow Serving container for the endpoint, because we trained with script mode. This serving container runs an implementation of a web server that is compatible with SageMaker hosting protocol. The [Using your own inference code]() document explains how SageMaker runs inference containers.

# %%
predictor = mnist_estimator.deploy(initial_instance_count=1, instance_type="ml.p2.xlarge")
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# ---------------!

# %% [markdown]
# Deployed the trained TensorFlow 2.1 model to an endpoint.

# %%
predictor2 = mnist_estimator2.deploy(initial_instance_count=1, instance_type="ml.p2.xlarge")
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# ---------------!

# %% [markdown]
# # (en caso de tener que partir desde acá)

# %%
import os
import sagemaker
from sagemaker import get_execution_role

sagemaker_session = sagemaker.Session()

role = get_execution_role()
region = sagemaker_session.boto_session.region_name

# %%
from sagemaker.tensorflow import TensorFlowModel

mnist_estimator = TensorFlowModel(
    model_data='s3://sagemaker-us-west-2-625806755153/tensorflow-training-2021-07-17-02-58-16-149/output/model.tar.gz',
    framework_version="1.15.2",
    role=role)

predictor = mnist_estimator.deploy(initial_instance_count=1, instance_type="ml.p2.xlarge")
# Out:
# update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# ---------------!

# %%
mnist_estimator = TensorFlowModel(
    model_data='czc',
    framework_version="1.15.2",c
    role=role)
c
predictor = mnist_estimator.deploy(initial_instance_count=1, instance_type="ml.p2.xlarge")

# %% [markdown]
# # Invoke the endpoint
#
# Let's download the training data and use that as input for inference.

# %%
import numpy as np

# !aws --region {region} s3 cp s3://sagemaker-sample-data-{region}/tensorflow/mnist/train_data.npy train_data.npy
# !aws --region {region} s3 cp s3://sagemaker-sample-data-{region}/tensorflow/mnist/train_labels.npy train_labels.npy

train_data = np.load("train_data.npy")
train_labels = np.load("train_labels.npy")
# Out:
# download: s3://sagemaker-sample-data-us-west-2/tensorflow/mnist/train_data.npy to ./train_data.npy
# download: s3://sagemaker-sample-data-us-west-2/tensorflow/mnist/train_labels.npy to ./train_labels.npy

# %% [markdown]
# The formats of the input and the output data correspond directly to the request and response formats of the `Predict` method in the [TensorFlow Serving REST API](https://www.tensorflow.org/serving/api_rest). SageMaker's TensforFlow Serving endpoints can also accept additional input formats that are not part of the TensorFlow REST API, including the simplified JSON format, line-delimited JSON objects ("jsons" or "jsonlines"), and CSV data.
#
# In this example we are using a `numpy` array as input, which will be serialized into the simplified JSON format. In addtion, TensorFlow serving can also process multiple items at once as you can see in the following code. You can find the complete documentation on how to make predictions against a TensorFlow serving SageMaker endpoint [here](https://github.com/aws/sagemaker-python-sdk/blob/master/src/sagemaker/tensorflow/deploying_tensorflow_serving.rst#making-predictions-against-a-sagemaker-endpoint).

# %%
predictions = predictor.predict(train_data[:50])
for i in range(0, 50):
    prediction = predictions["predictions"][i]["classes"]
    label = train_labels[i]
    print(
        "prediction is {}, label is {}, matched: {}".format(prediction, label, prediction == label)
    )
# Out:
# prediction is 7, label is 7, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 3, label is 2, matched: False
# prediction is 7, label is 7, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 2, label is 2, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 5, label is 5, matched: True
# prediction is 5, label is 5, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 1, label is 8, matched: False
# prediction is 8, label is 8, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 7, label is 7, matched: True

# %% [markdown]
# Examine the prediction result from the TensorFlow 2.1 model.

# %%
predictions2 = predictor2.predict(train_data[:50])
for i in range(0, 50):
    prediction = np.argmax(predictions2["predictions"][i])
    label = train_labels[i]
    print(
        "prediction is {}, label is {}, matched: {}".format(prediction, label, prediction == label)
    )

# %% [markdown]
# # Delete the endpoint
#
# Let's delete the endpoint we just created to prevent incurring any extra costs.

# %%
predictor.delete_endpoint()

# %% [markdown]
# Delete the TensorFlow 2.1 endpoint as well.

# %%
predictor2.delete_endpoint()
